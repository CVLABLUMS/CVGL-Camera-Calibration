# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(1)
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.compat.v1.Session(config=config)
import matplotlib.pyplot as plt
import PIL.Image as Image
import math
import numpy as np
import tensorflow.keras.backend as K
from tensorflow.keras.utils import plot_model
import json
from tensorflow.keras.losses import mse
import os
import glob
import random
#import cv2
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.inception_v3 import InceptionV3
import datetime
from tensorflow.keras.layers import Dense, Input, concatenate, Conv2D, MaxPooling2D, Flatten, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.callbacks import TensorBoard
# %matplotlib inline

from tensorflow.keras.losses import Loss
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def add_layer(tensor):
    return tensor[0] + tensor[1]

def mul_layer(tensor):
    return tensor[0] * tensor[1]

def div_layer(tensor):
    return tensor[0] / tensor[1]

def sub_layer(tensor):
    return tensor[0] - tensor[1]

def neg_layer(tensor):
    return -tensor

def cos_layer(tensor):
    return tf.math.cos(tensor)

def sin_layer(tensor):
    return tf.math.sin(tensor)

# %%
# feature extraction from left image

left_img = Input(shape = (150,150,3), name="left_image")

# feature extraction from right image
right_img = Input(shape = (150,150,3), name="right_image")

left_phi_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=left_img, input_shape=(150,150,3))
for layer in left_phi_model.layers:
  layer._name = layer._name+"f1_base"

left_phi_features = left_phi_model.output
left_flat = Flatten(name='left-phi-flattened')(left_phi_features)

right_phi_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=right_img, input_shape=(150,150,3))
for layer in right_phi_model.layers:
  layer._name = layer._name+"f2_base"

right_phi_features = right_phi_model.output
right_flat = Flatten(name='right-phi-flattened')(right_phi_features)

concat = concatenate([left_flat, right_flat])

# fx
dense_1 = Dense(120, activation = 'relu')(concat)
dense_2 = Dense(84, activation = 'relu')(dense_1)
pred_fx = Dense(1, name='fx')(dense_2)

# fy
dense_3 = Dense(120, activation = 'relu')(concat)
dense_4 = Dense(84, activation = 'relu')(dense_3)
pred_fy = Dense(1, name='fy')(dense_4)

# u0
dense_5 = Dense(120, activation = 'relu')(concat)
dense_6 = Dense(84, activation = 'relu')(dense_5)
pred_u0 = Dense(1, name='u0')(dense_6)

# v0
dense_7 = Dense(120, activation = 'relu')(concat)
dense_8 = Dense(84, activation = 'relu')(dense_7)
pred_v0 = Dense(1, name='v0')(dense_8)

# baseline
dense_9 = Dense(120, activation = 'relu')(concat)
dense_10 = Dense(84, activation = 'relu')(dense_9)
pred_baseline = Dense(1, name='baseline')(dense_10)

# tx
dense_11 = Dense(120, activation = 'relu')(concat)
dense_12 = Dense(84, activation = 'relu')(dense_11)
pred_x = Dense(1, name='x')(dense_12)

# ty
dense_13 = Dense(120, activation = 'relu')(concat)
dense_14 = Dense(84, activation = 'relu')(dense_13)
pred_y = Dense(1, name='y')(dense_14)

# tz
dense_15 = Dense(120, activation = 'relu')(concat)
dense_16 = Dense(84, activation = 'relu')(dense_15)
pred_z = Dense(1, name='z')(dense_16)

# pitch
dense_17 = Dense(120, activation = 'relu')(concat)
dense_18 = Dense(84, activation = 'relu')(dense_17)
pred_pitch = Dense(1, name='pitch')(dense_18)

# u
dense_19 = Dense(120, activation = 'relu')(concat)
dense_20 = Dense(84, activation = 'relu')(dense_19)
pred_u = Dense(1, name='u')(dense_20)

# v
dense_21 = Dense(120, activation = 'relu')(concat)
dense_22 = Dense(84, activation = 'relu')(dense_21)
pred_v = Dense(1, name='v')(dense_22)

# disparity
dense_23 = Dense(120, activation = 'relu')(concat)
dense_24 = Dense(84, activation = 'relu')(dense_23)
pred_disparity = Dense(1, name='disparity')(dense_24)

# w_xworld: alpha for X 3D point
dense_31 = Dense(120, activation = 'relu')(concat)
dense_32 = Dense(84, activation = 'relu')(dense_31)
w_xworld = Dense(1, name='w_xworld', activation = 'sigmoid')(dense_32)

# w_yworld: alpha for Y 3D point
dense_33 = Dense(120, activation = 'relu')(concat)
dense_34 = Dense(84, activation = 'relu')(dense_33)
w_yworld = Dense(1, name='w_yworld', activation = 'sigmoid')(dense_34)

# w_zworld: alpha for Z 3D point
dense_35 = Dense(120, activation = 'relu')(concat)
dense_36 = Dense(84, activation = 'relu')(dense_35)
w_zworld = Dense(1, name='w_zworld', activation = 'sigmoid')(dense_36)

#vp+_+ is for vanishing points

# alpha_vp1_1
dense_vp1_1_1 = Dense(120, activation = 'relu')(concat)
dense_vp1_1_2 = Dense(84, activation = 'relu')(dense_vp1_1_1)
alpha_vp1_1 = Dense(1, name='alpha_vp1_1', activation = 'sigmoid')(dense_vp1_1_2)

# alpha_vp1_2
dense_vp1_2_1 = Dense(120, activation = 'relu')(concat)
dense_vp1_2_2 = Dense(84, activation = 'relu')(dense_vp1_2_1)
alpha_vp1_2 = Dense(1, name='alpha_vp1_2', activation = 'sigmoid')(dense_vp1_2_2)

# alpha_vp2_1
dense_vp2_1_1 = Dense(120, activation = 'relu')(concat)
dense_vp2_1_2 = Dense(84, activation = 'relu')(dense_vp2_1_1)
alpha_vp2_1 = Dense(1, name='alpha_vp2_1', activation = 'sigmoid')(dense_vp2_1_2)

# alpha_vp2_2
dense_vp2_2_1 = Dense(120, activation = 'relu')(concat)
dense_vp2_2_2 = Dense(84, activation = 'relu')(dense_vp2_2_1)
alpha_vp2_2 = Dense(1, name='alpha_vp2_2', activation = 'sigmoid')(dense_vp2_2_2)

#wc+_+ is for word center

# alpha_wc1_1
dense_wc1_1_1 = Dense(120, activation = 'relu')(concat)
dense_wc1_1_2 = Dense(84, activation = 'relu')(dense_wc1_1_1)
alpha_wc1_1 = Dense(1, name='alpha_wc1_1', activation = 'sigmoid')(dense_wc1_1_2)

# alpha_wc1_2
dense_wc1_2_1 = Dense(120, activation = 'relu')(concat)
dense_wc1_2_2 = Dense(84, activation = 'relu')(dense_wc1_2_1)
alpha_wc1_2 = Dense(1, name='alpha_wc1_2', activation = 'sigmoid')(dense_wc1_2_2)

# alpha_con: alpha for all the constraints
dense_con1 = Dense(120, activation = 'relu')(concat)
dense_con2 = Dense(84, activation = 'relu')(dense_con1)
alpha_con = Dense(1, name='alpha_con', activation = 'sigmoid')(dense_con2)

# alpha_3d: alpha for all the 3d points
dense_3d1 = Dense(120, activation = 'relu')(concat)
dense_3d2 = Dense(84, activation = 'relu')(dense_3d1)
alpha_3d = Dense(1, name='alpha_3d', activation = 'sigmoid')(dense_3d2)

# For 3D point:

# xCam = (self.intrinsic.fx * self.extrinsic.baseline) / disparity
mul_1 = Lambda(mul_layer)([pred_fx, pred_baseline])
xCam = Lambda(div_layer)([mul_1, pred_disparity])

# yCam = - (xCam / self.intrinsic.fx) * (u - self.intrinsic.u0)
div_1 = Lambda(div_layer)([xCam, pred_fx])
sub_1 = Lambda(sub_layer)([pred_u, pred_u0])
yCam = Lambda(mul_layer)([Lambda(neg_layer)(div_1), sub_1])

# zCam = (xCam / self.intrinsic.fy) * (self.intrinsic.v0 - v)
div_2 = Lambda(div_layer)([xCam, pred_fy])
sub_2 = Lambda(sub_layer)([pred_v0, pred_v])
zCam = Lambda(mul_layer)([div_2, sub_2])

# Y = yCam + self.extrinsic.y
pred_yWorld = Lambda(add_layer)([yCam, pred_y])
pred_yWorld = Lambda(mul_layer, name='yWorld')([pred_yWorld, w_yworld]) * alpha_3d

# X = xCam * math.cos(self.extrinsic.pitch) + zCam * math.sin(self.extrinsic.pitch) + self.extrinsic.x
mul_2 = Lambda(mul_layer)([xCam, Lambda(cos_layer)(pred_pitch)])
mul_3 = Lambda(mul_layer)([zCam, Lambda(sin_layer)(pred_pitch)])
add_1 = Lambda(add_layer)([mul_2, mul_3])
pred_xWorld = Lambda(add_layer)([add_1, pred_x])
pred_xWorld = Lambda(mul_layer, name='xWorld')([pred_xWorld, w_xworld]) * alpha_3d

# Z = - xCam * math.sin(self.extrinsic.pitch) + zCam * math.cos(self.extrinsic.pitch) + self.extrinsic.z
mul_4 = Lambda(mul_layer)([Lambda(neg_layer)(xCam), Lambda(sin_layer)(pred_pitch)])
mul_5 = Lambda(mul_layer)([zCam, Lambda(cos_layer)(pred_pitch)])
add_2 = Lambda(add_layer)([mul_4, mul_5])
pred_zWorld = Lambda(add_layer)([add_2, pred_z])
pred_zWorld = Lambda(mul_layer, name='zWorld')([pred_zWorld, w_zworld]) * alpha_3d

# For Constraints

dim = tf.shape(pred_fx)[0]

k_00 = pred_fx
k_02 = pred_u0
k_11 = pred_fy
k_12 = pred_v0

# k = intrinsic matrix

k = tf.stack([
    tf.stack([k_00, tf.zeros((dim, 1), dtype=tf.float32), k_02], axis=1),
    tf.stack([tf.zeros((dim, 1), dtype=tf.float32), k_11, k_12], axis=1),
    tf.stack([tf.zeros((dim, 1), dtype=tf.float32), tf.zeros((dim, 1), dtype=tf.float32), tf.ones((dim, 1), dtype=tf.float32)], axis=1)
], axis=2)

k = tf.reshape(tf.transpose(tf.reshape(k, (dim, 3, 3)), perm=[0, 2, 1]), (dim, 3, 3))


r_pitch = tf.stack([
    tf.stack([tf.cos(pred_pitch), tf.zeros(shape=(dim, 1), dtype=tf.float32), tf.sin(pred_pitch)], axis=1),
    tf.stack([tf.zeros(shape=(dim, 1), dtype=tf.float32), tf.ones(shape=(dim, 1), dtype=tf.float32), tf.zeros(shape=(dim, 1), dtype=tf.float32)], axis=1),
    tf.stack([-tf.sin(pred_pitch), tf.zeros(shape=(dim, 1), dtype=tf.float32), tf.cos(pred_pitch)], axis=1)
], axis=2)


r_pitch = tf.reshape(tf.transpose(tf.reshape(r_pitch, (dim, 3, 3)), perm=[0, 2, 1]), (dim, 3, 3))

# t = translation
t = tf.stack([pred_x, pred_y, pred_z], axis=1)

# r = rotation + t
r = tf.concat([r_pitch, t], axis=2)

# projection matrix
p = tf.linalg.matmul(k, r) + 1

vanish_point_1 = tf.gather(p, [0, 2, 3], axis=2)

vp1_1 = Lambda(mul_layer, name='vp1_1')([
    alpha_vp1_1,
    vanish_point_1[:, :, 0][:, 0:1] / ((vanish_point_1[:, :, 0][:, 2:3] + 0.00001) + 0.00001)
]) * alpha_con

vp1_2 = Lambda(mul_layer, name='vp1_2')([
    alpha_vp1_2,
    vanish_point_1[:, :, 0][:, 1:2] / ((vanish_point_1[:, :, 0][:, 2:3] + 0.00001) + 0.00001)
]) * alpha_con

vp2_1 = Lambda(mul_layer, name='vp2_1')([
    alpha_vp2_1,
    vanish_point_1[:, :, 1][:, 0:1] / ((vanish_point_1[:, :, 1][:, 2:3] + 0.00001) + 0.00001)
]) * alpha_con

vp2_2 = Lambda(mul_layer, name='vp2_2')([
    alpha_vp2_2,
    vanish_point_1[:, :, 1][:, 1:2] / ((vanish_point_1[:, :, 1][:, 2:3] + 0.00001) + 0.00001)
]) * alpha_con

wc1_1 = Lambda(mul_layer, name='wc1_1')([
    alpha_wc1_1,
    vanish_point_1[:, :, 2][:, 1:2] / ((vanish_point_1[:, :, 2][:, 2:3] + 0.00001) + 0.00001)
]) * alpha_con

wc1_2 = Lambda(mul_layer, name='wc1_2')([
    alpha_wc1_2,
    vanish_point_1[:, :, 2][:, 1:2] / ((vanish_point_1[:, :, 2][:, 2:3] + 0.00001) + 0.00001)
]) * alpha_con


# Row Constraints

# 1) Product of Rows
row_prod = r_pitch[:, 0] * r_pitch[:, 2]
row_product = tf.reduce_sum(row_prod, axis=1, name="rot_row_product")

# 2) Determinant
determinant = tf.linalg.det(r_pitch, name='determinant')

# 3) Identity

pred_pitch_transposed = tf.transpose(r_pitch, perm=(0, 2, 1))
element_wise_mul = r_pitch * pred_pitch_transposed
sum_axis_1 = tf.reduce_sum(element_wise_mul, axis=1)
rot_identity = tf.reduce_sum(sum_axis_1, axis=1, name='rot_identity')

# create model
model = Model(inputs=[left_img, right_img], outputs=[pred_fx, pred_fy, pred_u0, pred_v0, pred_baseline, pred_disparity, pred_x, pred_y, pred_z, pred_pitch, pred_xWorld,pred_yWorld,pred_zWorld, vp1_1, vp1_2, vp2_1, vp2_2, wc1_1, wc1_2, row_product, determinant, rot_identity])

# set output types
target1 = tf.placeholder(dtype='float32', shape=(1,1))
target2 = tf.placeholder(dtype='float32', shape=(1,1))
target3 = tf.placeholder(dtype='float32', shape=(1,1))
target4 = tf.placeholder(dtype='float32', shape=(1,1))
target5 = tf.placeholder(dtype='float32', shape=(1,1))
target6 = tf.placeholder(dtype='float32', shape=(1,1))
target7 = tf.placeholder(dtype='float32', shape=(1,1))
target8 = tf.placeholder(dtype='float32', shape=(1,1))
target9 = tf.placeholder(dtype='float32', shape=(1,1))
target10 = tf.placeholder(dtype='float32', shape=(1,1))
target11 = tf.placeholder(dtype='float32', shape=(1,1))
target12 = tf.placeholder(dtype='float32', shape=(1,1))
target13 = tf.placeholder(dtype='float32', shape=(1,1))

t_vp1_1 = tf.placeholder(dtype='float32', shape=(1,1))
t_vp1_2 = tf.placeholder(dtype='float32', shape=(1,1))
t_vp2_1 = tf.placeholder(dtype='float32', shape=(1,1))
t_vp2_2 = tf.placeholder(dtype='float32', shape=(1,1))
t_wc1_1 = tf.placeholder(dtype='float32', shape=(1,1))
t_wc1_2 = tf.placeholder(dtype='float32', shape=(1,1))

row = tf.placeholder(dtype='float32', shape=(1,1))
det = tf.placeholder(dtype='float32', shape=(1,1))
row_idt = tf.placeholder(dtype='float32', shape=(1,1))


learning_rate = 0.001

# compile model
model.compile(loss="mae", target_tensors=[target1, target2, target3, target4, target5, target6, target7, target8, target9, target10, target11, target12, target13, t_vp1_1, t_vp1_2, t_vp2_1, t_vp2_2, t_wc1_1, t_wc1_2, row, det, row_idt], optimizer=optimizers.legacy.Adam(lr=learning_rate));
#plot_model(model, to_file='model.png')

# %%
import numpy as np
data_path = 'your pth/'
Fx = np.load(data_path+"fx.npy", mmap_mode='r')
Fy = np.load(data_path+"fy.npy", mmap_mode='r')
U0 = np.load(data_path+"U0.npy", mmap_mode='r')
V0 = np.load(data_path+"V0.npy", mmap_mode='r')
Disparity = np.load(data_path+"disparity.npy", mmap_mode='r')
Tx = np.load(data_path+"x.npy", mmap_mode='r')
Ty = np.load(data_path+"y.npy", mmap_mode='r') 
Tz = np.load(data_path+"z.npy", mmap_mode='r')
Baseline = np.load(data_path+"baseline.npy", mmap_mode='r')
Pitch = np.load(data_path+"pitch.npy", mmap_mode='r')
X = np.load(data_path+"xworld.npy", mmap_mode='r')
Y = np.load(data_path+"yworld.npy", mmap_mode='r')
Z = np.load(data_path+"zworld.npy", mmap_mode='r')
Left_images = np.load(data_path+"left_img.npy", mmap_mode='r')
Right_images = np.load(data_path+"right_img.npy", mmap_mode='r')

# %%
# Getting Vanishing points, World Center & rotation matrix constraints for the training.

train_num = int(len(Fx)*0.7)#- 40000

pred_fx = np.array(Fx[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_fy = np.array(Fy[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_pitch = np.array(Pitch[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_x = np.array(Tx[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_y = np.array(Ty[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_z = np.array(Tz[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_u0 = np.array(U0[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_v0 = np.array(V0[0:train_num]).reshape(train_num, 1).astype(np.float32)

dim = pred_fx.shape[0]

k_00 = pred_fx
k_02 = pred_u0
k_11 = pred_fy
k_12 = pred_v0

k = np.stack([
    np.stack([k_00, np.zeros((dim, 1), dtype=np.float32), k_02], axis=1),
    np.stack([np.zeros((dim, 1), dtype=np.float32), k_11, k_12], axis=1),
    np.stack([np.zeros((dim, 1), dtype=np.float32), np.zeros((dim, 1), dtype=np.float32), np.ones((dim, 1), dtype=np.float32)], axis=1)
], axis=2)

k = np.reshape(np.transpose(np.reshape(k, (dim, 3, 3), order='F'), (0, 2, 1)), (dim, 3, 3))


pred_pitch= np.stack([
    np.stack([np.cos(pred_pitch), np.zeros((dim, 1), dtype=np.float32), np.sin(pred_pitch)], axis=1),
    np.stack([np.zeros((dim, 1), dtype=np.float32), np.ones((dim, 1), dtype=np.float32), np.zeros((dim, 1), dtype=np.float32)], axis=1),
    np.stack([-np.sin(pred_pitch), np.zeros((dim, 1), dtype=np.float32), np.cos(pred_pitch)], axis=1)
], axis=2)

pred_pitch = np.reshape(np.transpose(np.reshape(pred_pitch, (dim, 3, 3), order='F'), (0, 2, 1)), (dim, 3, 3))

t = np.stack([pred_x, pred_y, pred_z], axis=1)

r = pred_pitch
r = np.concatenate([r, t], axis=2)

# Projection matrix
p = np.matmul(k, r) + 1

vanish_point_1 =  p[:, :, [0, 2, 3]]
               
train_vp1_1 = vanish_point_1[:, :, 0][:, 0:1]/vanish_point_1[:, :, 0][:, 2:3]
train_vp1_2 = vanish_point_1[:, :, 0][:, 1:2]/vanish_point_1[:, :, 0][:, 2:3]
train_vp2_1 = vanish_point_1[:, :, 1][:, 0:1]/vanish_point_1[:, :, 1][:, 2:3]
train_vp2_2 = vanish_point_1[:, :, 1][:, 1:2]/vanish_point_1[:, :, 1][:, 2:3]
train_wc_1_1 = vanish_point_1[:, :, 2][:, 0:1]/vanish_point_1[:, :, 2][:, 2:3]
train_wc_1_2 = vanish_point_1[:, :, 2][:, 1:2]/vanish_point_1[:, :, 2][:, 2:3]

# %%
# Getting Vanishing points, World Center & rotation matrix constraints for the validation.

train_num = int(len(Fx)*0.7)
valid_reshape = int(len(Fx)) -  int(len(Fx)*0.7)

pred_fx = np.array(Fx[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_fy = np.array(Fy[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_pitch = np.array(Pitch[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_x = np.array(Tx[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_y = np.array(Ty[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_z = np.array(Tz[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_u0 = np.array(U0[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_v0 = np.array(V0[train_num:]).reshape(valid_reshape, 1).astype(np.float32)

dim = pred_fx.shape[0]

k_00 = pred_fx
k_02 = pred_u0
k_11 = pred_fy
k_12 = pred_v0

k = np.stack([
    np.stack([k_00, np.zeros((dim, 1), dtype=np.float32), k_02], axis=1),
    np.stack([np.zeros((dim, 1), dtype=np.float32), k_11, k_12], axis=1),
    np.stack([np.zeros((dim, 1), dtype=np.float32), np.zeros((dim, 1), dtype=np.float32), np.ones((dim, 1), dtype=np.float32)], axis=1)
], axis=2)

k = np.reshape(np.transpose(np.reshape(k, (dim, 3, 3), order='F'), (0, 2, 1)), (dim, 3, 3))

pred_pitch= np.stack([
    np.stack([np.cos(pred_pitch), np.zeros((dim, 1), dtype=np.float32), np.sin(pred_pitch)], axis=1),
    np.stack([np.zeros((dim, 1), dtype=np.float32), np.ones((dim, 1), dtype=np.float32), np.zeros((dim, 1), dtype=np.float32)], axis=1),
    np.stack([-np.sin(pred_pitch), np.zeros((dim, 1), dtype=np.float32), np.cos(pred_pitch)], axis=1)
], axis=2)

pred_pitch = np.reshape(np.transpose(np.reshape(pred_pitch, (dim, 3, 3), order='F'), (0, 2, 1)), (dim, 3, 3))

t = np.stack([pred_x, pred_y, pred_z], axis=1)

r = np.concatenate([pred_pitch, t], axis=2)

# Projection matrix
p = np.matmul(k, r) + 1

vanish_point_1 =  p[:, :, [0, 2, 3]]

test_vp1_1 = vanish_point_1[:, :, 0][:, 0:1]/vanish_point_1[:, :, 0][:, 2:3]
test_vp1_2 = vanish_point_1[:, :, 0][:, 1:2]/vanish_point_1[:, :, 0][:, 2:3]
test_vp2_1 = vanish_point_1[:, :, 1][:, 0:1]/vanish_point_1[:, :, 1][:, 2:3]
test_vp2_2 = vanish_point_1[:, :, 1][:, 1:2]/vanish_point_1[:, :, 1][:, 2:3]
test_wc_1_1 = vanish_point_1[:, :, 2][:, 0:1]/vanish_point_1[:, :, 2][:, 2:3]
test_wc_1_2 = vanish_point_1[:, :, 2][:, 1:2]/vanish_point_1[:, :, 2][:, 2:3]

# %%
row_product_train = np.zeros((int(Fx.shape[0] * 0.7), 1))
row_product_test = np.zeros((int(Fx.shape[0] * 0.3), 1))

rot_det_train = np.ones((int(Fx.shape[0] * 0.7), 1))
rot_det_test = np.ones((int(Fx.shape[0] * 0.3), 1))

rot_idt_train = np.ones((int(Fx.shape[0] * 0.7), 1)) * 3
rot_idt_test = np.ones((int(Fx.shape[0] * 0.3), 1)) * 3

# %%
import os
from tensorflow.keras.callbacks import TensorBoard, LearningRateScheduler
from keras.applications.inception_v3 import InceptionV3
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model
from keras.layers import Dense, Flatten, Input
#from utils_regressor_focal_dist import RotNetDataGenerator, angle_error, CustomModelCheckpoint
from keras import optimizers
import numpy as np
import glob, math
from shutil import copyfile
import datetime, random
import tensorflow as tf
#from keras.backend.tensorflow_backend import set_session

model_name = 'model_multi_class/'
SAVE = "UGCL_VP_WC_R/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '/'
# Save
output_folder = SAVE + model_name
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

output_log = output_folder + "Log/"
if not os.path.exists(output_log):
    os.makedirs(output_log)

output_weight = output_folder + "Best/"
if not os.path.exists(output_weight):
    os.makedirs(output_weight)


input_shape = (112, 112, 3)

tensorboard = TensorBoard(log_dir=output_log)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto', restore_best_weights=True)

csv_logger = CSVLogger('UGCL_VP_WC_R.log')


checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath=output_weight + "weights_{epoch:02d}_{val_loss}.h5",
    monitor="val_loss",
    verbose=0,
    save_best_only=True,
    save_weights_only=True
)

history = model.fit(
    x=[Left_images[:int(len(Left_images)*0.7)], Right_images[:int(len(Left_images)*0.7)]],
    y=[Fx[:int(len(Left_images)*0.7)], Fy[:int(len(Left_images)*0.7)], U0[:int(len(Left_images)*0.7)], V0[:int(len(Left_images)*0.7)], Baseline[:int(len(Left_images)*0.7)], Disparity[:int(len(Left_images)*0.7)], Tx[:int(len(Left_images)*0.7)], Ty[:int(len(Left_images)*0.7)], Tz[:int(len(Left_images)*0.7)], Pitch[:int(len(Left_images)*0.7)], X[:int(len(Left_images)*0.7)], Y[:int(len(Left_images)*0.7)], Z[:int(len(Left_images)*0.7)], train_vp1_1, train_vp1_2, train_vp2_1, train_vp2_2, train_wc_1_1, train_wc_1_2, row_product_train, rot_det_train, rot_idt_train],
    batch_size=32,
    epochs=100,
    verbose=2,
    shuffle=True,
    initial_epoch=0,
    validation_data=([Left_images[int(len(Left_images)*0.7):], Right_images[int(len(Left_images)*0.7):]], [Fx[int(len(Left_images)*0.7):], Fy[int(len(Left_images)*0.7):], U0[int(len(Left_images)*0.7):], V0[int(len(Left_images)*0.7):], Baseline[int(len(Left_images)*0.7):], Disparity[int(len(Left_images)*0.7):], Tx[int(len(Left_images)*0.7):], Ty[int(len(Left_images)*0.7):], Tz[int(len(Left_images)*0.7):], Pitch[int(len(Left_images)*0.7):], X[int(len(Left_images)*0.7):], Y[int(len(Left_images)*0.7):], Z[int(len(Left_images)*0.7):], test_vp1_1, test_vp1_2, test_vp2_1, test_vp2_2, test_wc_1_1, test_wc_1_2, row_product_test, rot_det_test, rot_idt_test]),
    callbacks=[tensorboard, checkpointer, csv_logger]
)
# Out:
# Train on 44520 samples, validate on 19080 samples
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 44520/44520 - 700s - loss: 431.1970 - fx_loss: 12.7580 - fy_loss: 12.4997 - u0_loss: 2.5168 - v0_loss: 2.3997 - baseline_loss: 0.7122 - disparity_loss: 4.0321 - x_loss: 0.3102 - y_loss: 0.2114 - z_loss: 0.2745 - pitch_loss: 1.2051 - tf_op_layer_mul_1_loss: 39.3268 - tf_op_layer_mul_loss: 30.8408 - tf_op_layer_mul_2_loss: 30.4726 - tf_op_layer_mul_3_loss: 95.2983 - tf_op_layer_mul_4_loss: 6.6466 - tf_op_layer_mul_5_loss: 37.8959 - tf_op_layer_mul_6_loss: 37.9063 - tf_op_layer_mul_7_loss: 80.2921 - tf_op_layer_mul_8_loss: 34.6708 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.2244e-08 - tf_op_layer_rot_identity_loss: 0.8889 - val_loss: 431.4861 - val_fx_loss: 7.1570 - val_fy_loss: 7.5619 - val_u0_loss: 3.3257 - val_v0_loss: 2.1784 - val_baseline_loss: 0.1667 - val_disparity_loss: 4.8301 - val_x_loss: 0.2026 - val_y_loss: 0.1380 - val_z_loss: 0.1253 - val_pitch_loss: 0.0623 - val_tf_op_layer_mul_1_loss: 44.1673 - val_tf_op_layer_mul_loss: 34.1845 - val_tf_op_layer_mul_2_loss: 33.8685 - val_tf_op_layer_mul_3_loss: 95.6516 - val_tf_op_layer_mul_4_loss: 6.6219 - val_tf_op_layer_mul_5_loss: 37.8866 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4754 - val_tf_op_layer_mul_8_loss: 34.9807 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 9.6595e-09 - val_tf_op_layer_rot_identity_loss: 0.0223 - 700s/epoch - 16ms/sample
# Epoch 2/100
# 44520/44520 - 308s - loss: 414.7451 - fx_loss: 7.6186 - fy_loss: 7.5522 - u0_loss: 1.1619 - v0_loss: 1.2051 - baseline_loss: 0.1661 - disparity_loss: 3.2680 - x_loss: 0.2043 - y_loss: 0.1322 - z_loss: 0.1319 - pitch_loss: 0.0652 - tf_op_layer_mul_1_loss: 39.2566 - tf_op_layer_mul_loss: 30.8374 - tf_op_layer_mul_2_loss: 30.4619 - tf_op_layer_mul_3_loss: 95.3091 - tf_op_layer_mul_4_loss: 6.5564 - tf_op_layer_mul_5_loss: 37.8949 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2968 - tf_op_layer_mul_8_loss: 34.6800 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0006e-08 - tf_op_layer_rot_identity_loss: 0.0258 - val_loss: 421.9499 - val_fx_loss: 5.7063 - val_fy_loss: 5.5772 - val_u0_loss: 0.6106 - val_v0_loss: 0.5824 - val_baseline_loss: 0.1512 - val_disparity_loss: 3.0875 - val_x_loss: 0.2003 - val_y_loss: 0.1305 - val_z_loss: 0.1250 - val_pitch_loss: 0.0531 - val_tf_op_layer_mul_1_loss: 44.1409 - val_tf_op_layer_mul_loss: 34.1341 - val_tf_op_layer_mul_2_loss: 33.8164 - val_tf_op_layer_mul_3_loss: 95.6693 - val_tf_op_layer_mul_4_loss: 6.6197 - val_tf_op_layer_mul_5_loss: 37.8877 - val_tf_op_layer_mul_6_loss: 37.9050 - val_tf_op_layer_mul_7_loss: 80.4656 - val_tf_op_layer_mul_8_loss: 35.0033 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 1.0221e-08 - val_tf_op_layer_rot_identity_loss: 0.0231 - 308s/epoch - 7ms/sample
# Epoch 3/100
# 44520/44520 - 306s - loss: 411.4916 - fx_loss: 6.3857 - fy_loss: 6.4435 - u0_loss: 0.8398 - v0_loss: 0.8971 - baseline_loss: 0.1589 - disparity_loss: 3.0412 - x_loss: 0.2004 - y_loss: 0.1270 - z_loss: 0.1251 - pitch_loss: 0.0475 - tf_op_layer_mul_1_loss: 39.2526 - tf_op_layer_mul_loss: 30.8346 - tf_op_layer_mul_2_loss: 30.4584 - tf_op_layer_mul_3_loss: 95.3061 - tf_op_layer_mul_4_loss: 6.5564 - tf_op_layer_mul_5_loss: 37.8974 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2920 - tf_op_layer_mul_8_loss: 34.6750 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 9.8993e-09 - tf_op_layer_rot_identity_loss: 0.0182 - val_loss: 426.3524 - val_fx_loss: 6.2517 - val_fy_loss: 6.8370 - val_u0_loss: 2.0513 - val_v0_loss: 1.8525 - val_baseline_loss: 0.1634 - val_disparity_loss: 2.9735 - val_x_loss: 0.2000 - val_y_loss: 0.1252 - val_z_loss: 0.1251 - val_pitch_loss: 0.0410 - val_tf_op_layer_mul_1_loss: 44.1560 - val_tf_op_layer_mul_loss: 34.1456 - val_tf_op_layer_mul_2_loss: 33.8279 - val_tf_op_layer_mul_3_loss: 95.6555 - val_tf_op_layer_mul_4_loss: 6.6230 - val_tf_op_layer_mul_5_loss: 37.8891 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.
op_layer_mul_loss: 34.1404 - val_tf_op_layer_mul_2_loss: 33.8205 - val_tf_op_layer_mul_3_loss: 95.6677 - val_tf_op_layer_mul_4_loss: 6.6252 - val_tf_op_layer_mul_5_loss: 37.8881 - val_tf_op_layer_mul_6_loss: 37.9048 - val_tf_op_layer_mul_7_loss: 80.4986 - val_tf_op_layer_mul_8_loss: 34.9826 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 1.0146e-08 - val_tf_op_layer_rot_identity_loss: 0.0239 - 306s/epoch - 7ms/sample
# Epoch 6/100
# 44520/44520 - 309s - loss: 408.0756 - fx_loss: 5.1307 - fy_loss: 5.2488 - u0_loss: 0.4980 - v0_loss: 0.5722 - baseline_loss: 0.1459 - disparity_loss: 2.7516 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1252 - pitch_loss: 0.0418 - tf_op_layer_mul_1_loss: 39.2544 - tf_op_layer_mul_loss: 30.8366 - tf_op_layer_mul_2_loss: 30.4604 - tf_op_layer_mul_3_loss: 95.3068 - tf_op_layer_mul_4_loss: 6.5578 - tf_op_layer_mul_5_loss: 37.8968 - tf_op_layer_mul_6_loss: 37.9063 - tf_op_layer_mul_7_loss: 80.2902 - tf_op_layer_mul_8_loss: 34.6730 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 9.9743e-09 - tf_op_layer_rot_identity_loss: 0.0170 - val_loss: 420.4914 - val_fx_loss: 4.9846 - val_fy_loss: 4.9680 - val_u0_loss: 0.7081 - val_v0_loss: 0.6112 - val_baseline_loss: 0.1428 - val_disparity_loss: 2.8584 - val_x_loss: 0.2003 - val_y_loss: 0.1248 - val_z_loss: 0.1250 - val_pitch_loss: 0.0358 - val_tf_op_layer_mul_1_loss: 44.1481 - val_tf_op_layer_mul_loss: 34.1377 - val_tf_op_layer_mul_2_loss: 33.8178 - val_tf_op_layer_mul_3_loss: 95.6554 - val_tf_op_layer_mul_4_loss: 6.6220 - val_tf_op_layer_mul_5_loss: 37.8899 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4585 - val_tf_op_layer_mul_8_loss: 34.9715 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 1.0483e-08 - val_tf_op_layer_rot_identity_loss: 0.0180 - 309s/epoch - 7ms/sample
# Epoch 7/100
# 44520/44520 - 307s - loss: 407.9293 - fx_loss: 5.1047 - fy_loss: 5.2577 - u0_loss: 0.4755 - v0_loss: 0.4715 - baseline_loss: 0.1441 - disparity_loss: 2.7503 - x_loss: 0.2005 - y_loss: 0.1254 - z_loss: 0.1252 - pitch_loss: 0.0402 - tf_op_layer_mul_1_loss: 39.2631 - tf_op_layer_mul_loss: 30.8400 - tf_op_layer_mul_2_loss: 30.4627 - tf_op_layer_mul_3_loss: 95.3089 - tf_op_layer_mul_4_loss: 6.5580 - tf_op_layer_mul_5_loss: 37.8950 - tf_op_layer_mul_6_loss: 37.9063 - tf_op_layer_mul_7_loss: 80.2776 - tf_op_layer_mul_8_loss: 34.6735 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.
- tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 9.8485e-09 - tf_op_layer_rot_identity_loss: 0.0179 - val_loss: 422.6184 - val_fx_loss: 6.3200 - val_fy_loss: 6.1680 - val_u0_loss: 0.3791 - val_v0_loss: 0.3576 - val_baseline_loss: 0.1427 - val_disparity_loss: 3.0260 - val_x_loss: 0.2003 - val_y_loss: 0.1248 - val_z_loss: 0.1249 - val_pitch_loss: 0.0419 - val_tf_op_layer_mul_1_loss: 44.1394 - val_tf_op_layer_mul_loss: 34.1358 - val_tf_op_layer_mul_2_loss: 33.8177 - val_tf_op_layer_mul_3_loss: 95.6505 - val_tf_op_layer_mul_4_loss: 6.6249 - val_tf_op_layer_mul_5_loss: 37.8881 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.5007 - val_tf_op_layer_mul_8_loss: 34.9808 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 7.5005e-09 - val_tf_op_layer_rot_identity_loss: 0.0133 - 306s/epoch - 7ms/sample
# Epoch 18/100
# 44520/44520 - 307s - loss: 403.0505 - fx_loss: 3.0112 - fy_loss: 3.0642 - u0_loss: 0.2950 - v0_loss: 0.3125 - baseline_loss: 0.1440 - disparity_loss: 2.5021 - x_loss: 0.2004 - y_loss: 0.1254 - z_loss: 0.1251 - pitch_loss: 0.0370 - tf_op_layer_mul_1_loss: 39.2975 - tf_op_layer_mul_loss: 30.8771 - tf_op_layer_mul_2_loss: 30.5023 - tf_op_layer_mul_3_loss: 95.3037 - tf_op_layer_mul_4_loss: 6.5556 - tf_op_layer_mul_5_loss: 37.8958 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.3017 - tf_op_layer_mul_8_loss: 34.6709 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0603e-08 - tf_op_layer_rot_identity_loss: 0.0183 - val_loss: 426.8534 - val_fx_loss: 8.8136 - val_fy_loss: 8.2766 - val_u0_loss: 0.6747 - val_v0_loss: 0.0567 - val_baseline_loss: 0.1429 - val_disparity_loss: 2.6677 - val_x_loss: 0.2000 - val_y_loss: 0.1248 - val_z_loss: 0.1249 - val_pitch_loss: 0.0435 - val_tf_op_layer_mul_1_loss: 44.1331 - val_tf_op_layer_mul_loss: 34.1298 - val_tf_op_layer_mul_2_loss: 33.8118 - val_tf_op_layer_mul_3_loss: 95.6533 - val_tf_op_layer_mul_4_loss: 6.6233 - val_tf_op_layer_mul_5_loss: 37.8865 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4701 - val_tf_op_layer_mul_8_loss: 34.9746 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 5.5536e-09 - val_tf_op_layer_rot_identity_loss: 0.0134 - 307s/epoch - 7ms/sample
# Epoch 19/100
# 44520/44520 - 306s - loss: 402.7156 - fx_loss: 2.9012 - fy_loss: 2.9591 - u0_loss: 0.2529 - v0_loss: 0.2920 - baseline_loss: 0.1440 - disparity_loss: 2.4454 - x_loss: 0.2004 - y_loss: 0.1254 - z_loss: 0.1251 - pitch_loss: 0.0387 - tf_op_layer_mul_1_loss: 39.2543 - tf_op_layer_mul_loss: 30.8362 - tf_op_layer_mul_2_loss: 30.4601 - tf_op_layer_mul_3_loss: 95.3049 - tf_op_layer_mul_4_loss: 6.5559 - tf_op_layer_mul_5_loss: 37.8974 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2898 - tf_op_layer_mul_8_loss: 34.6857 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0113e-08 - tf_op_layer_rot_identity_loss: 0.0173 - val_loss: 433.4824 - val_fx_loss: 11.8457 - val_fy_loss: 11.8699 - val_u0_loss: 0.1202 - val_v0_loss: 0.2089 - val_baseline_loss: 0.1427 - val_disparity_loss: 3.0726 - val_x_loss: 0.2000 - val_y_loss: 0.1250 - val_z_loss: 0.1249 - val_pitch_loss: 0.0385 - val_tf_op_layer_mul_1_loss: 44.1401 - val_tf_op_layer_mul_loss: 34.1350 - val_tf_op_layer_mul_2_loss: 33.8162 - val_tf_op_layer_mul_3_loss: 95.6585 - val_tf_op_layer_mul_4_loss: 6.6183 - val_tf_op_layer_mul_5_loss: 37.8877 - val_tf_op_layer_mul_6_loss: 37.9050 - val_tf_op_layer_mul_7_loss: 80.4631 - val_tf_op_layer_mul_8_loss: 34.9778 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 8.8047e-09 - val_tf_op_layer_rot_identity_loss: 0.0152 - 306s/epoch - 7ms/sample
# Epoch 20/100
# 44520/44520 - 307s - loss: 402.3496 - fx_loss: 2.7693 - fy_loss: 2.8186 - u0_loss: 0.2612 - v0_loss: 0.2728 - baseline_loss: 0.1440 - disparity_loss: 2.3619 - x_loss: 0.2005 - y_loss: 0.1254 - z_loss: 0.1251 - pitch_loss: 0.0357 - tf_op_layer_mul_1_loss: 39.2605 - tf_op_layer_mul_loss: 30.8405 - tf_op_layer_mul_2_loss: 30.4646 - tf_op_layer_mul_3_loss: 95.3010 - tf_op_layer_mul_4_loss: 6.5560 - tf_op_layer_mul_5_loss: 37.8964 - tf_op_layer_mul_6_loss: 37.9063 - tf_op_layer_mul_7_loss: 80.2707 - tf_op_layer_mul_8_loss: 34.6754 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 9.9448e-09 - tf_op_layer_rot_identity_loss: 0.0189 - val_loss: 436.8065 - val_fx_loss: 13.7201 - val_fy_loss: 12.9397 - val_u0_loss: 0.7508 - val_v0_loss: 0.3059 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.7207 - val_x_loss: 0.2004 - val_y_loss: 0.1249 - val_z_loss: 0.1249 - val_pitch_loss: 0.0405 - val_tf_op_layer_mul_1_loss: 44.1461 - val_tf_op_layer_mul_loss: 34.1381 - val_tf_op_layer_mul_2_loss: 33.8208 - val_tf_op_layer_mul_3_loss: 95.6745 - val_tf_op_layer_mul_4_loss: 6.6231 - val_tf_op_layer_mul_5_loss: 37.8877 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.5086 - val_tf_op_layer_mul_8_loss: 34.9760 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 6.7455e-09 - val_tf_op_layer_rot_identity_loss: 0.0227 - 307s/epoch - 7ms/sample
# Epoch 21/100
# 44520/44520 - 307s - loss: 401.8785 - fx_loss: 2.5941 - fy_loss: 2.6314 - u0_loss: 0.2501 - v0_loss: 0.2562 - baseline_loss: 0.1440 - disparity_loss: 2.2789 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0360 - tf_op_layer_mul_1_loss: 39.2566 - tf_op_layer_mul_loss: 30.8385 - tf_op_layer_mul_2_loss: 30.4622 - tf_op_layer_mul_3_loss: 95.3027 - tf_op_layer_mul_4_loss: 6.5557 - tf_op_layer_mul_5_loss: 37.8977 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2798 - tf_op_layer_mul_8_loss: 34.6733 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0036e-08 - tf_op_layer_rot_identity_loss: 0.0187 - val_loss: 422.1405 - val_fx_loss: 5.9836 - val_fy_loss: 6.0744 - val_u0_loss: 0.5734 - val_v0_loss: 0.4148 - val_baseline_loss: 0.1429 - val_disparity_loss: 2.7273 - val_x_loss: 0.2002 - val_y_loss: 0.1249 - val_z_loss: 0.1251 - val_pitch_loss: 0.0389 - val_tf_op_layer_mul_1_loss: 44.1269 - val_tf_op_layer_mul_loss: 34.1235 - val_tf_op_layer_mul_2_loss: 33.8054 - val_tf_op_layer_mul_3_loss: 95.6644 - val_tf_op_layer_mul_4_loss: 6.6269 - val_tf_op_layer_mul_5_loss: 37.8914 - val_tf_op_layer_mul_6_loss: 37.9048 - val_tf_op_layer_mul_7_loss: 80.4798 - val_tf_op_layer_mul_8_loss: 34.9800 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 8.4677e-09 - val_tf_op_layer_rot_identity_loss: 0.0170 - 307s/epoch - 7ms/sample
# Epoch 22/100
# 44520/44520 - 306s - loss: 401.7388 - fx_loss: 2.5574 - fy_loss: 2.6056 - u0_loss: 0.2492 - v0_loss: 0.2802 - baseline_loss: 0.1440 - disparity_loss: 2.1849 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0363 - tf_op_layer_mul_1_loss: 39.2728 - tf_op_layer_mul_loss: 30.8466 - tf_op_layer_mul_2_loss: 30.4687 - tf_op_layer_mul_3_loss: 95.3147 - tf_op_layer_mul_4_loss: 6.5566 - tf_op_layer_mul_5_loss: 37.8979 - tf_op_layer_mul_6_loss: 37.9063 - tf_op_layer_mul_7_loss: 80.3006 - tf_op_layer_mul_8_loss: 34.6810 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 9.7816e-09 - tf_op_layer_rot_identity_loss: 0.0185 - val_loss: 427.7685 - val_fx_loss: 9.1214 - val_fy_loss: 8.8879 - val_u0_loss: 0.4228 - val_v0_loss: 0.2185 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.7644 - val_x_loss: 0.2000 - val_y_loss: 0.1249 - val_z_loss: 0.1250 - val_pitch_loss: 0.0354 - val_tf_op_layer_mul_1_loss: 44.1317 - val_tf_op_layer_mul_loss: 34.1284 - val_tf_op_layer_mul_2_loss: 33.8104 - val_tf_op_layer_mul_3_loss: 95.6428 - val_tf_op_layer_mul_4_loss: 6.6254 - val_tf_op_layer_mul_5_loss: 37.8900 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4737 - val_tf_op_layer_mul_8_loss: 34.9831 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 6.2400e-09 - val_tf_op_layer_rot_identity_loss: 0.0182 - 306s/epoch - 7ms/sample
# Epoch 23/100
# 44520/44520 - 306s - loss: 401.4341 - fx_loss: 2.4533 - fy_loss: 2.4968 - u0_loss: 0.2448 - v0_loss: 0.2604 - baseline_loss: 0.1440 - disparity_loss: 2.1129 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0355 - tf_op_layer_mul_1_loss: 39.2694 - tf_op_layer_mul_loss: 30.8487 - tf_op_layer_mul_2_loss: 30.4716 - tf_op_layer_mul_3_loss: 95.3080 - tf_op_layer_mul_4_loss: 6.5568 - tf_op_layer_mul_5_loss: 37.8969 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2719 - tf_op_layer_mul_8_loss: 34.6838 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss:
- val_baseline_loss: 0.1427 - val_disparity_loss: 2.7344 - val_x_loss: 0.2001 - val_y_loss: 0.1248 - val_z_loss: 0.1249 - val_pitch_loss: 0.0322 - val_tf_op_layer_mul_1_loss: 44.1380 - val_tf_op_layer_mul_loss: 34.1300 - val_tf_op_layer_mul_2_loss: 33.8121 - val_tf_op_layer_mul_3_loss: 95.6750 - val_tf_op_layer_mul_4_loss: 6.6248 - val_tf_op_layer_mul_5_loss: 37.8873 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.5301 - val_tf_op_layer_mul_8_loss: 34.9671 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 8.0309e-09 - val_tf_op_layer_rot_identity_loss: 0.0191 - 306s/epoch - 7ms/sample
# Epoch 26/100
# 44520/44520 - 308s - loss: 400.5654 - fx_loss: 2.1722 - fy_loss: 2.2020 - u0_loss: 0.2326 - v0_loss: 0.2322 - baseline_loss: 0.1440 - disparity_loss: 1.8667 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0345 - tf_op_layer_mul_1_loss: 39.2766 - tf_op_layer_mul_loss: 30.8514 - tf_op_layer_mul_2_loss: 30.4727 - tf_op_layer_mul_3_loss: 95.3076 - tf_op_layer_mul_4_loss: 6.5572 - tf_op_layer_mul_5_loss: 37.8975 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.3018 - tf_op_layer_mul_8_loss: 34.6795 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 9.8110e-09 - tf_op_layer_rot_identity_loss: 0.0191 - val_loss: 415.6534 - val_fx_loss: 3.2096 - val_fy_loss: 3.2210 - val_u0_loss: 0.1071 - val_v0_loss: 0.1342 - val_baseline_loss: 0.1436 - val_disparity_loss: 2.6271 - val_x_loss: 0.2001 - val_y_loss: 0.1248 - val_z_loss: 0.1250 - val_pitch_loss: 0.0330 - val_tf_op_layer_mul_1_loss: 44.1634 - val_tf_op_layer_mul_loss: 34.1589 - val_tf_op_layer_mul_2_loss: 33.8416 - val_tf_op_layer_mul_3_loss: 95.6488 - val_tf_op_layer_mul_4_loss: 6.6201 - val_tf_op_layer_mul_5_loss: 37.8871 - val_tf_op_layer_mul_6_loss: 37.9050 - val_tf_op_layer_mul_7_loss: 80.4492 - val_tf_op_layer_mul_8_loss: 34.9648 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 2.3924e-08 - val_tf_op_layer_rot_identity_loss: 0.0179 - 308s/epoch - 7ms/sample
# Epoch 27/100
# 44520/44520 - 306s - loss: 400.3781 - fx_loss: 2.1135 - fy_loss: 2.1331 - u0_loss: 0.2320 - v0_loss: 0.2493 - baseline_loss: 0.1440 - disparity_loss: 1.7855 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0331 - tf_op_layer_mul_1_loss: 39.2634 - tf_op_layer_mul_loss: 30.8421 - tf_op_layer_mul_2_loss: 30.4664 - tf_op_layer_mul_3_loss: 95.3047 - tf_op_layer_mul_4_loss: 6.5563 - tf_op_layer_mul_5_loss: 37.8960 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2857 - tf_op_layer_mul_8_loss: 34.6787 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0124e-08 - tf_op_layer_rot_identity_loss: 0.0199 - val_loss: 416.5113 - val_fx_loss: 3.6745 - val_fy_loss: 3.5137 - val_u0_loss: 0.1128 - val_v0_loss: 0.2126 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.6365 - val_x_loss: 0.2000 - val_y_loss: 0.1249 - val_z_loss: 0.1249 - val_pitch_loss: 0.0246 - val_tf_op_layer_mul_1_loss: 44.1898 - val_tf_op_layer_mul_loss: 34.1647 - val_tf_op_layer_mul_2_loss: 33.8395 - val_tf_op_layer_mul_3_loss: 95.6485 - val_tf_op_layer_mul_4_loss: 6.6223 - val_tf_op_layer_mul_5_loss: 37.8906 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4609 - val_tf_op_layer_mul_8_loss: 34.9726 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 7.9997e-09 - val_tf_op_layer_rot_identity_loss: 0.0264 - 306s/epoch - 7ms/sample
# Epoch 28/100
# 44520/44520 - 306s - loss: 400.0489 - fx_loss: 2.0258 - fy_loss: 2.0505 - u0_loss: 0.1988 - v0_loss: 0.1973 - baseline_loss: 0.1440 - disparity_loss: 1.7147 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0343 - tf_op_layer_mul_1_loss: 39.2709 - tf_op_layer_mul_loss: 30.8511 - tf_op_layer_mul_2_loss: 30.4759 - tf_op_layer_mul_3_loss: 95.3039 - tf_op_layer_mul_4_loss: 6.5562 - tf_op_layer_mul_5_loss: 37.8976 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2844 - tf_op_layer_mul_8_loss: 34.6699 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0354e-08 - tf_op_layer_rot_identity_loss: 0.0193 - val_loss: 421.4365 - val_fx_loss: 5.6419 - val_fy_loss: 5.6754 - val_u0_loss: 0.3503 - val_v0_loss: 0.6726 - val_baseline_loss: 0.1432 - val_disparity_loss: 2.7263 - val_x_loss: 0.2000 - val_y_loss: 0.1249 - val_z_loss: 0.1249 - val_pitch_loss: 0.0440 - val_tf_op_layer_mul_1_loss: 44.1412 - val_tf_op_layer_mul_loss: 34.1320 - val_tf_op_layer_mul_2_loss: 33.8129 - val_tf_op_layer_mul_3_loss: 95.6635 - val_tf_op_layer_mul_4_loss: 6.6230 - val_tf_op_layer_mul_5_loss: 37.8905 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4964 - val_tf_op_layer_mul_8_loss: 34.9828 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 7.4880e-09 - val_tf_op_layer_rot_identity_loss: 0.0137 - 306s/epoch - 7ms/sample
# Epoch 29/100
# 44520/44520 - 306s - loss: 399.9375 - fx_loss: 1.9844 - fy_loss: 1.9998 - u0_loss: 0.2327 - v0_loss: 0.2261 - baseline_loss: 0.1440 - disparity_loss: 1.6305 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0343 - tf_op_layer_mul_1_loss: 39.2549 - tf_op_layer_mul_loss: 30.8357 - tf_op_layer_mul_2_loss: 30.4602 - tf_op_layer_mul_3_loss: 95.3060 - tf_op_layer_mul_4_loss: 6.5557 - tf_op_layer_mul_5_loss: 37.8955 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2829 - tf_op_layer_mul_8_loss: 34.6824 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0151e-08 - tf_op_layer_rot_identity_loss: 0.0191 - val_loss: 416.8917 - val_fx_loss: 3.3731 - val_fy_loss: 3.3174 - val_u0_loss: 0.1564 - val_v0_loss: 0.7445 - val_baseline_loss: 0.1428 - val_disparity_loss: 2.9404 - val_x_loss: 0.2002 - val_y_loss: 0.1248 - val_z_loss: 0.1249 - val_pitch_loss: 0.0304 - val_tf_op_layer_mul_1_loss: 44.1282 - val_tf_op_layer_mul_loss: 34.1267 - val_tf_op_layer_mul_2_loss: 33.8087 - val_tf_op_layer_mul_3_loss: 95.6473 - val_tf_op_layer_mul_4_loss: 6.6212 - val_tf_op_layer_mul_5_loss: 37.8889 - val_tf_op_layer_mul_6_loss: 37.9050 - val_tf_op_layer_mul_7_loss: 80.4771 - val_tf_op_layer_mul_8_loss: 34.9835 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 7.8125e-09 - val_tf_op_layer_rot_identity_loss: 0.0215 - 306s/epoch - 7ms/sample
# Epoch 30/100
# 44520/44520 - 305s - loss: 399.7147 - fx_loss: 1.9137 - fy_loss: 1.9291 - u0_loss: 0.2114 - v0_loss: 0.2356 - baseline_loss: 0.1441 - disparity_loss: 1.5640 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0333 - tf_op_layer_mul_1_loss: 39.2609 - tf_op_layer_mul_loss: 30.8418 - tf_op_layer_mul_2_loss: 30.4662 - tf_op_layer_mul_3_loss: 95.2937 - tf_op_layer_mul_4_loss: 6.5561 - tf_op_layer_mul_5_loss: 37.8967 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2810 - tf_op_layer_mul_8_loss: 34.6689 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0073e-08 - tf_op_layer_rot_identity_loss: 0.0195 - val_loss: 418.2195 - val_fx_loss: 4.2024 - val_fy_loss: 4.3151 - val_u0_loss: 0.5949 - val_v0_loss: 0.1243 - val_baseline_loss: 0.1430 - val_disparity_loss: 2.6124 - val_x_loss: 0.2001 - val_y_loss: 0.1248 - val_z_loss: 0.1249 - val_pitch_loss: 0.0378 - val_tf_op_layer_mul_1_loss: 44.1290 - val_tf_op_layer_mul_loss: 34.1292 - val_tf_op_layer_mul_2_loss: 33.8106 - val_tf_op_layer_mul_3_loss: 95.6448 - val_tf_op_layer_mul_4_loss: 6.6205 - val_tf_op_layer_mul_5_loss: 37.8879 - val_tf_op_layer_mul_6_loss: 37.9050 - val_tf_op_layer_mul_7_loss: 80.4396 - val_tf_op_layer_mul_8_loss: 34.9771 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 9.4661e-09 - val_tf_op_layer_rot_identity_loss: 0.0244 - 305s/epoch - 7ms/sample
# Epoch 31/100
# 44520/44520 - 306s - loss: 399.6761 - fx_loss: 1.9233 - fy_loss: 1.9413 - u0_loss: 0.2301 - v0_loss: 0.2261 - baseline_loss: 0.1440 - disparity_loss: 1.4903 - x_loss: 0.2004 - y_loss: 0.1252 - z_loss: 0.1251 - pitch_loss: 0.0323 - tf_op_layer_mul_1_loss: 39.2537 - tf_op_layer_mul_loss: 30.8364 - tf_op_layer_mul_2_loss: 30.4606 - tf_op_layer_mul_3_loss: 95.3051 - tf_op_layer_mul_4_loss: 6.5565 - tf_op_layer_mul_5_loss: 37.8970 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2875 - tf_op_layer_mul_8_loss: 34.6682 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0518e-08 - tf_op_layer_rot_identity_loss: 0.0199 - val_loss: 417.8372 - val_fx_loss: 4.2237 - val_fy_loss: 4.1694 - val_u0_loss: 0.2350 - val_v0_loss: 0.1077 - val_baseline_loss: 0.1426 - val_disparity_loss: 2.7309 - val_x_loss: 0.2000 - val_y_loss: 0.1250 - val_z_loss: 0.1256 - val_pitch_loss: 0.0404 - val_tf_op_layer_mul_1_loss: 44.1509 - val_tf_op_layer_mul_loss: 34.1400 - val_tf_op_layer_mul_2_loss: 33.8203 - val_tf_op_layer_mul_3_loss: 95.6687 - val_tf_op_layer_mul_4_loss: 6.6230 - val_tf_op_layer_mul_5_loss: 37.8875 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.5058 - val_tf_op_layer_mul_8_loss: 34.9992 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 7.2197e-09 - val_tf_op_layer_rot_identity_loss: 0.0199 - 306s/epoch - 7ms/sample
# Epoch 32/100
# 44520/44520 - 305s - loss: 399.3864 - fx_loss: 1.8198 - fy_loss: 1.8309 - u0_loss: 0.2201 - v0_loss: 0.2148 - baseline_loss: 0.1439 - disparity_loss: 1.4369 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0332 - tf_op_layer_mul_1_loss: 39.2517 - tf_op_layer_mul_loss: 30.8347 - tf_op_layer_mul_2_loss: 30.4586 - tf_op_layer_mul_3_loss: 95.3003 - tf_op_layer_mul_4_loss: 6.5571 - tf_op_layer_mul_5_loss: 37.8964 - tf_op_layer_mul_6_loss: 37.9063 - tf_op_layer_mul_7_loss: 80.2721 - tf_op_layer_mul_8_loss: 34.6802 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0159e-08 - tf_op_layer_rot_identity_loss: 0.0198 - val_loss: 416.2212 - val_fx_loss: 3.4978 - val_fy_loss: 3.5253 - val_u0_loss: 0.0751 - val_v0_loss: 0.1719 - val_baseline_loss: 0.1430 - val_disparity_loss: 2.5932 - val_x_loss: 0.2001 - val_y_loss: 0.1248 - val_z_loss: 0.1250 - val_pitch_loss: 0.0288 - val_tf_op_layer_mul_1_loss: 44.6564 - val_tf_op_layer_mul_loss: 34.6633 - val_tf_op_layer_mul_2_loss: 34.2789 - val_tf_op_layer_mul_3_loss: 95.6386 - val_tf_op_layer_mul_4_loss: 6.6245 - val_tf_op_layer_mul_5_loss: 37.8865 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4831 - val_tf_op_layer_mul_8_loss: 34.9810 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 7.5442e-09 - val_tf_op_layer_rot_identity_loss: 0.0233 - 305s/epoch - 7ms/sample
# Epoch 33/100
# 44520/44520 - 307s - loss: 399.2324 - fx_loss: 1.8005 - fy_loss: 1.8123 - u0_loss: 0.2062 - v0_loss: 0.1795 - baseline_loss: 0.1440 - disparity_loss: 1.3708 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0333 - tf_op_layer_mul_1_loss: 39.2950 - tf_op_layer_mul_loss: 30.8615 - tf_op_layer_mul_2_loss: 30.4805 - tf_op_layer_mul_3_loss: 95.3157 - tf_op_layer_mul_4_loss: 6.5561 - tf_op_layer_mul_5_loss: 37.8977 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2772 - tf_op_layer_mul_8_loss: 34.6829 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0443e-08 - tf_op_layer_rot_identity_loss: 0.0197 - val_loss: 415.5115 - val_fx_loss: 2.7041 - val_fy_loss: 2.6995 - val_u0_loss: 0.5054 - val_v0_loss: 0.6357 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.6054 - val_x_loss: 0.2000 - val_y_loss: 0.1251 - val_z_loss: 0.1249 - val_pitch_loss: 0.0286 - val_tf_op_layer_mul_1_loss: 44.1356 - val_tf_op_layer_mul_loss: 34.1314 - val_tf_op_layer_mul_2_loss: 33.8129 - val_tf_op_layer_mul_3_loss: 95.6519 - val_tf_op_layer_mul_4_loss: 6.6228 - val_tf_op_layer_mul_5_loss: 37.8882 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4912 - val_tf_op_layer_mul_8_loss: 34.9910 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 7.2135e-09 - val_tf_op_layer_rot_identity_loss: 0.0235 - 307s/epoch - 7ms/sample
# Epoch 34/100
# ...
# Epoch 90/100
# 44520/44520 - 306s - loss: 209.8674 - fx_loss: 0.8611 - fy_loss: 1.0868 - u0_loss: 0.1760 - v0_loss: 0.1190 - baseline_loss: 0.1439 - disparity_loss: 0.5631 - x_loss: 0.2003 - y_loss: 0.1256 - z_loss: 0.1260 - pitch_loss: 0.0067 - tf_op_layer_mul_1_loss: 39.2557 - tf_op_layer_mul_loss: 30.8367 - tf_op_layer_mul_2_loss: 30.4611 - tf_op_layer_mul_3_loss: 0.8935 - tf_op_layer_mul_4_loss: 6.5557 - tf_op_layer_mul_5_loss: 0.3218 - tf_op_layer_mul_6_loss: 0.0608 - tf_op_layer_mul_7_loss: 80.2915 - tf_op_layer_mul_8_loss: 17.7175 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0135e-08 - tf_op_layer_rot_identity_loss: 0.0393 - val_loss: 231.3655 - val_fx_loss: 3.4247 - val_fy_loss: 3.0679 - val_u0_loss: 0.0582 - val_v0_loss: 0.1372 - val_baseline_loss: 0.1428 - val_disparity_loss: 2.5217 - val_x_loss: 0.2001 - val_y_loss: 0.1249 - val_z_loss: 0.1257 - val_pitch_loss: 0.0130 - val_tf_op_layer_mul_1_loss: 44.1745 - val_tf_op_layer_mul_loss: 34.1726 - val_tf_op_layer_mul_2_loss: 33.8535 - val_tf_op_layer_mul_3_loss: 3.3174 - val_tf_op_layer_mul_4_loss: 6.6236 - val_tf_op_layer_mul_5_loss: 0.6202 - val_tf_op_layer_mul_6_loss: 0.0656 - val_tf_op_layer_mul_7_loss: 80.5032 - val_tf_op_layer_mul_8_loss: 18.2226 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 1.3273e-08 - val_tf_op_layer_rot_identity_loss: 0.0388 - 306s/epoch - 7ms/sample
# Epoch 91/100
# 44520/44520 - 305s - loss: 209.7304 - fx_loss: 0.8347 - fy_loss: 1.0566 - u0_loss: 0.1345 - v0_loss: 0.1277 - baseline_loss: 0.1438 - disparity_loss: 0.5545 - x_loss: 0.2003 - y_loss: 0.1255 - z_loss: 0.1260 - pitch_loss: 0.0066 - tf_op_layer_mul_1_loss: 39.2838 - tf_op_layer_mul_loss: 30.8651 - tf_op_layer_mul_2_loss: 30.4920 - tf_op_layer_mul_3_loss: 0.8652 - tf_op_layer_mul_4_loss: 6.5570 - tf_op_layer_mul_5_loss: 0.3067 - tf_op_layer_mul_6_loss: 0.0651 - tf_op_layer_mul_7_loss: 80.2850 - tf_op_layer_mul_8_loss: 17.7146 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 9.8726e-09 - tf_op_layer_rot_identity_loss: 0.0395 - val_loss: 230.8132 - val_fx_loss: 2.8361 - val_fy_loss: 2.8722 - val_u0_loss: 0.3861 - val_v0_loss: 0.4212 - val_baseline_loss: 0.1431 - val_disparity_loss: 2.5111 - val_x_loss: 0.2000 - val_y_loss: 0.1254 - val_z_loss: 0.1258 - val_pitch_loss: 0.0140 - val_tf_op_layer_mul_1_loss: 44.1493 - val_tf_op_layer_mul_loss: 34.1507 - val_tf_op_layer_mul_2_loss: 33.8344 - val_tf_op_layer_mul_3_loss: 2.8599 - val_tf_op_layer_mul_4_loss: 6.6230 - val_tf_op_layer_mul_5_loss: 0.5621 - val_tf_op_layer_mul_6_loss: 0.1976 - val_tf_op_layer_mul_7_loss: 80.4814 - val_tf_op_layer_mul_8_loss: 18.2425 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 9.6533e-09 - val_tf_op_layer_rot_identity_loss: 0.0353 - 305s/epoch - 7ms/sample
# Epoch 92/100
# 44520/44520 - 306s - loss: 209.8298 - fx_loss: 0.8403 - fy_loss: 1.0577 - u0_loss: 0.1418 - v0_loss: 0.1289 - baseline_loss: 0.1439 - disparity_loss: 0.5776 - x_loss: 0.2003 - y_loss: 0.1255 - z_loss: 0.1261 - pitch_loss: 0.0074 - tf_op_layer_mul_1_loss: 39.2897 - tf_op_layer_mul_loss: 30.8553 - tf_op_layer_mul_2_loss: 30.4787 - tf_op_layer_mul_3_loss: 0.8817 - tf_op_layer_mul_4_loss: 6.5566 - tf_op_layer_mul_5_loss: 0.3461 - tf_op_layer_mul_6_loss: 0.0658 - tf_op_layer_mul_7_loss: 80.2895 - tf_op_layer_mul_8_loss: 17.7131 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 9.9100e-09 - tf_op_layer_rot_identity_loss: 0.0394 - val_loss: 230.0593 - val_fx_loss: 2.6067 - val_fy_loss: 2.8708 - val_u0_loss: 0.3839 - val_v0_loss: 0.2572 - val_baseline_loss: 0.1429 - val_disparity_loss: 2.5292 - val_x_loss: 0.2002 - val_y_loss: 0.1252 - val_z_loss: 0.1253 - val_pitch_loss: 0.0096 - val_tf_op_layer_mul_1_loss: 44.1317 - val_tf_op_layer_mul_loss: 34.1293 - val_tf_op_layer_mul_2_loss: 33.8129 - val_tf_op_layer_mul_3_loss: 2.6414 - val_tf_op_layer_mul_4_loss: 6.6222 - val_tf_op_layer_mul_5_loss: 0.4659 - val_tf_op_layer_mul_6_loss: 0.1194 - val_tf_op_layer_mul_7_loss: 80.5058 - val_tf_op_layer_mul_8_loss: 18.2656 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 9.7781e-09 - val_tf_op_layer_rot_identity_loss: 0.0367 - 306s/epoch - 7ms/sample
# Epoch 93/100
# 44520/44520 - 306s - loss: 209.8615 - fx_loss: 0.8618 - fy_loss: 1.0807 - u0_loss: 0.1533 - v0_loss: 0.1291 - baseline_loss: 0.1439 - disparity_loss: 0.5617 - x_loss: 0.2003 - y_loss: 0.1255 - z_loss: 0.1260 - pitch_loss: 0.0071 - tf_op_layer_mul_1_loss: 39.2545 - tf_op_layer_mul_loss: 30.8365 - tf_op_layer_mul_2_loss: 30.4608 - tf_op_layer_mul_3_loss: 0.9014 - tf_op_layer_mul_4_loss: 6.5562 - tf_op_layer_mul_5_loss: 0.3340 - tf_op_layer_mul_6_loss: 0.0660 - tf_op_layer_mul_7_loss: 80.2753 - tf_op_layer_mul_8_loss: 17.6955 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0188e-08 - tf_op_layer_rot_identity_loss: 0.0393 - val_loss: 233.3676 - val_fx_loss: 3.7239 - val_fy_loss: 3.3984 - val_u0_loss: 0.5485 - val_v0_loss: 0.4217 - val_baseline_loss: 0.1429 - val_disparity_loss: 2.5500 - val_x_loss: 0.2000 - val_y_loss: 0.1250 - val_z_loss: 0.1257 - val_pitch_loss: 0.0100 - val_tf_op_layer_mul_1_loss: 44.1269 - val_tf_op_layer_mul_loss: 34.1239 - val_tf_op_layer_mul_2_loss: 33.8062 - val_tf_op_layer_mul_3_loss: 3.7106 - val_tf_op_layer_mul_4_loss: 6.6228 - val_tf_op_layer_mul_5_loss: 0.6270 - val_tf_op_layer_mul_6_loss: 0.2081 - val_tf_op_layer_mul_7_loss: 80.4527 - val_tf_op_layer_mul_8_loss: 18.2545 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 1.1644e-08 - val_tf_op_layer_rot_identity_loss: 0.0396 - 306s/epoch - 7ms/sample
# Epoch 94/100
# 44520/44520 - 306s - loss: 209.7444 - fx_loss: 0.8260 - fy_loss: 1.0482 - u0_loss: 0.1506 - v0_loss: 0.1261 - baseline_loss: 0.1439 - disparity_loss: 0.5565 - x_loss: 0.2003 - y_loss: 0.1255 - z_loss: 0.1260 - pitch_loss: 0.0070 - tf_op_layer_mul_1_loss: 39.2578 - tf_op_layer_mul_loss: 30.8378 - tf_op_layer_mul_2_loss: 30.4611 - tf_op_layer_mul_3_loss: 0.8588 - tf_op_layer_mul_4_loss: 6.5565 - tf_op_layer_mul_5_loss: 0.3285 - tf_op_layer_mul_6_loss: 0.0645 - tf_op_layer_mul_7_loss: 80.2767 - tf_op_layer_mul_8_loss: 17.7069 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0028e-08 - tf_op_layer_rot_identity_loss: 0.0394 - val_loss: 228.6955 - val_fx_loss: 2.1797 - val_fy_loss: 2.2527 - val_u0_loss: 0.4981 - val_v0_loss: 0.2452 - val_baseline_loss: 0.1428 - val_disparity_loss: 2.5152 - val_x_loss: 0.2001 - val_y_loss: 0.1252 - val_z_loss: 0.1259 - val_pitch_loss: 0.0098 - val_tf_op_layer_mul_1_loss: 44.1353 - val_tf_op_layer_mul_loss: 34.1384 - val_tf_op_layer_mul_2_loss: 33.8208 - val_tf_op_layer_mul_3_loss: 2.2574 - val_tf_op_layer_mul_4_loss: 6.6226 - val_tf_op_layer_mul_5_loss: 0.5321 - val_tf_op_layer_mul_6_loss: 0.1276 - val_tf_op_layer_mul_7_loss: 80.4693 - val_tf_op_layer_mul_8_loss: 18.1584 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 8.8920e-09 - val_tf_op_layer_rot_identity_loss: 0.0428 - 306s/epoch - 7ms/sample
# Epoch 95/100
# 44520/44520 - 306s - loss: 209.8177 - fx_loss: 0.8539 - fy_loss: 1.0675 - u0_loss: 0.1465 - v0_loss: 0.1178 - baseline_loss: 0.1439 - disparity_loss: 0.5509 - x_loss: 0.2003 - y_loss: 0.1255 - z_loss: 0.1259 - pitch_loss: 0.0073 - tf_op_layer_mul_1_loss: 39.2697 - tf_op_layer_mul_loss: 30.8464 - tf_op_layer_mul_2_loss: 30.4704 - tf_op_layer_mul_3_loss: 0.8928 - tf_op_layer_mul_4_loss: 6.5557 - tf_op_layer_mul_5_loss: 0.3418 - tf_op_layer_mul_6_loss: 0.0605 - tf_op_layer_mul_7_loss: 80.2922 - tf_op_layer_mul_8_loss: 17.7097 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0055e-08 - tf_op_layer_rot_identity_loss: 0.0391 - val_loss: 228.8083 - val_fx_loss: 2.2388 - val_fy_loss: 2.3062 - val_u0_loss: 0.1849 - val_v0_loss: 0.4334 - val_baseline_loss: 0.1426 - val_disparity_loss: 2.5353 - val_x_loss: 0.1999 - val_y_loss: 0.1250 - val_z_loss: 0.1266 - val_pitch_loss: 0.0098 - val_tf_op_layer_mul_1_loss: 44.1374 - val_tf_op_layer_mul_loss: 34.1294 - val_tf_op_layer_mul_2_loss: 33.8106 - val_tf_op_layer_mul_3_loss: 2.2695 - val_tf_op_layer_mul_4_loss: 6.6202 - val_tf_op_layer_mul_5_loss: 0.5048 - val_tf_op_layer_mul_6_loss: 0.2165 - val_tf_op_layer_mul_7_loss: 80.5188 - val_tf_op_layer_mul_8_loss: 18.2034 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 9.2789e-09 - val_tf_op_layer_rot_identity_loss: 0.0407 - 306s/epoch - 7ms/sample
# Epoch 96/100
# 44520/44520 - 305s - loss: 209.7128 - fx_loss: 0.8182 - fy_loss: 1.0375 - u0_loss: 0.1671 - v0_loss: 0.1296 - baseline_loss: 0.1439 - disparity_loss: 0.5422 - x_loss: 0.2002 - y_loss: 0.1256 - z_loss: 0.1261 - pitch_loss: 0.0066 - tf_op_layer_mul_1_loss: 39.2587 - tf_op_layer_mul_loss: 30.8415 - tf_op_layer_mul_2_loss: 30.4662 - tf_op_layer_mul_3_loss: 0.8507 - tf_op_layer_mul_4_loss: 6.5561 - tf_op_layer_mul_5_loss: 0.3141 - tf_op_layer_mul_6_loss: 0.0661 - tf_op_layer_mul_7_loss: 80.2907 - tf_op_layer_mul_8_loss: 17.7163 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0368e-08 - tf_op_layer_rot_identity_loss: 0.0395 - val_loss: 229.6764 - val_fx_loss: 2.4556 - val_fy_loss: 2.3953 - val_u0_loss: 0.7048 - val_v0_loss: 0.3282 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.5074 - val_x_loss: 0.1999 - val_y_loss: 0.1252 - val_z_loss: 0.1256 - val_pitch_loss: 0.0095 - val_tf_op_layer_mul_1_loss: 44.2740 - val_tf_op_layer_mul_loss: 34.2055 - val_tf_op_layer_mul_2_loss: 33.8720 - val_tf_op_layer_mul_3_loss: 2.5293 - val_tf_op_layer_mul_4_loss: 6.6226 - val_tf_op_layer_mul_5_loss: 0.4582 - val_tf_op_layer_mul_6_loss: 0.1610 - val_tf_op_layer_mul_7_loss: 80.4713 - val_tf_op_layer_mul_8_loss: 18.2124 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 9.5035e-09 - val_tf_op_layer_rot_identity_loss: 0.0394 - 305s/epoch - 7ms/sample
# Epoch 97/100
# 44520/44520 - 306s - loss: 209.6667 - fx_loss: 0.8183 - fy_loss: 1.0459 - u0_loss: 0.1450 - v0_loss: 0.1281 - baseline_loss: 0.1439 - disparity_loss: 0.5390 - x_loss: 0.2003 - y_loss: 0.1255 - z_loss: 0.1260 - pitch_loss: 0.0063 - tf_op_layer_mul_1_loss: 39.2537 - tf_op_layer_mul_loss: 30.8354 - tf_op_layer_mul_2_loss: 30.4596 - tf_op_layer_mul_3_loss: 0.8511 - tf_op_layer_mul_4_loss: 6.5558 - tf_op_layer_mul_5_loss: 0.2982 - tf_op_layer_mul_6_loss: 0.0652 - tf_op_layer_mul_7_loss: 80.2686 - tf_op_layer_mul_8_loss: 17.7008 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0255e-08 - tf_op_layer_rot_identity_loss: 0.0394 - val_loss: 229.0277 - val_fx_loss: 2.3584 - val_fy_loss: 2.4930 - val_u0_loss: 0.3098 - val_v0_loss: 0.2599 - val_baseline_loss: 0.1428 - val_disparity_loss: 2.5245 - val_x_loss: 0.2001 - val_y_loss: 0.1252 - val_z_loss: 0.1256 - val_pitch_loss: 0.0113 - val_tf_op_layer_mul_1_loss: 44.1282 - val_tf_op_layer_mul_loss: 34.1255 - val_tf_op_layer_mul_2_loss: 33.8077 - val_tf_op_layer_mul_3_loss: 2.3643 - val_tf_op_layer_mul_4_loss: 6.6236 - val_tf_op_layer_mul_5_loss: 0.4965 - val_tf_op_layer_mul_6_loss: 0.1186 - val_tf_op_layer_mul_7_loss: 80.4345 - val_tf_op_layer_mul_8_loss: 18.1835 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 9.7843e-09 - val_tf_op_layer_rot_identity_loss: 0.0358 - 306s/epoch - 7ms/sample
# Epoch 98/100
# 44520/44520 - 306s - loss: 209.6515 - fx_loss: 0.8189 - fy_loss: 1.0426 - u0_loss: 0.1450 - v0_loss: 0.1203 - baseline_loss: 0.1439 - disparity_loss: 0.5348 - x_loss: 0.2004 - y_loss: 0.1255 - z_loss: 0.1260 - pitch_loss: 0.0063 - tf_op_layer_mul_1_loss: 39.2606 - tf_op_layer_mul_loss: 30.8416 - tf_op_layer_mul_2_loss: 30.4657 - tf_op_layer_mul_3_loss: 0.8520 - tf_op_layer_mul_4_loss: 6.5552 - tf_op_layer_mul_5_loss: 0.2960 - tf_op_layer_mul_6_loss: 0.0614 - tf_op_layer_mul_7_loss: 80.2931 - tf_op_layer_mul_8_loss: 17.7079 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0210e-08 - tf_op_layer_rot_identity_loss: 0.0395 - val_loss: 229.0195 - val_fx_loss: 2.3812 - val_fy_loss: 2.4671 - val_u0_loss: 0.1446 - val_v0_loss: 0.2615 - val_baseline_loss: 0.1442 - val_disparity_loss: 2.5077 - val_x_loss: 0.2002 - val_y_loss: 0.1253 - val_z_loss: 0.1260 - val_pitch_loss: 0.0137 - val_tf_op_layer_mul_1_loss: 44.1865 - val_tf_op_layer_mul_loss: 34.1745 - val_tf_op_layer_mul_2_loss: 33.8498 - val_tf_op_layer_mul_3_loss: 2.4235 - val_tf_op_layer_mul_4_loss: 6.6232 - val_tf_op_layer_mul_5_loss: 0.6062 - val_tf_op_layer_mul_6_loss: 0.1169 - val_tf_op_layer_mul_7_loss: 80.4546 - val_tf_op_layer_mul_8_loss: 18.1869 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 1.3765e-08 - val_tf_op_layer_rot_identity_loss: 0.0347 - 306s/epoch - 7ms/sample
# Epoch 99/100
# 44520/44520 - 308s - loss: 209.6584 - fx_loss: 0.8229 - fy_loss: 1.0559 - u0_loss: 0.1383 - v0_loss: 0.1238 - baseline_loss: 0.1439 - disparity_loss: 0.5309 - x_loss: 0.2003 - y_loss: 0.1255 - z_loss: 0.1259 - pitch_loss: 0.0064 - tf_op_layer_mul_1_loss: 39.2686 - tf_op_layer_mul_loss: 30.8446 - tf_op_layer_mul_2_loss: 30.4676 - tf_op_layer_mul_3_loss: 0.8532 - tf_op_layer_mul_4_loss: 6.5564 - tf_op_layer_mul_5_loss: 0.2972 - tf_op_layer_mul_6_loss: 0.0631 - tf_op_layer_mul_7_loss: 80.2862 - tf_op_layer_mul_8_loss: 17.6974 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 1.0378e-08 - tf_op_layer_rot_identity_loss: 0.0393 - val_loss: 226.6891 - val_fx_loss: 1.7471 - val_fy_loss: 1.8037 - val_u0_loss: 0.1385 - val_v0_loss: 0.0890 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.5423 - val_x_loss: 0.2002 - val_y_loss: 0.1254 - val_z_loss: 0.1263 - val_pitch_loss: 0.0093 - val_tf_op_layer_mul_1_loss: 44.1328 - val_tf_op_layer_mul_loss: 34.1287 - val_tf_op_layer_mul_2_loss: 33.8121 - val_tf_op_layer_mul_3_loss: 1.7868 - val_tf_op_layer_mul_4_loss: 6.6220 - val_tf_op_layer_mul_5_loss: 0.4200 - val_tf_op_layer_mul_6_loss: 0.0464 - val_tf_op_layer_mul_7_loss: 80.4752 - val_tf_op_layer_mul_8_loss: 18.1917 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 9.8717e-09 - val_tf_op_layer_rot_identity_loss: 0.0406 - 308s/epoch - 7ms/sample
# Epoch 100/100
# 44520/44520 - 305s - loss: 209.5301 - fx_loss: 0.7836 - fy_loss: 1.0173 - u0_loss: 0.1497 - v0_loss: 0.1164 - baseline_loss: 0.1439 - disparity_loss: 0.5283 - x_loss: 0.2003 - y_loss: 0.1255 - z_loss: 0.1262 - pitch_loss: 0.0059 - tf_op_layer_mul_1_loss: 39.2618 - tf_op_layer_mul_loss: 30.8422 - tf_op_layer_mul_2_loss: 30.4656 - tf_op_layer_mul_3_loss: 0.8132 - tf_op_layer_mul_4_loss: 6.5569 - tf_op_layer_mul_5_loss: 0.2804 - tf_op_layer_mul_6_loss: 0.0592 - tf_op_layer_mul_7_loss: 80.2826 - tf_op_layer_mul_8_loss: 17.7087 - tf_op_layer_rot_row_product_loss: 0.0000e+00 - tf_op_layer_determinant_loss: 9.9100e-09 - tf_op_layer_rot_identity_loss: 0.0395 - val_loss: 233.4629 - val_fx_loss: 3.7113 - val_fy_loss: 4.0905 - val_u0_loss: 0.3209 - val_v0_loss: 0.3588 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.5113 - val_x_loss: 0.1999 - val_y_loss: 0.1254 - val_z_loss: 0.1254 - val_pitch_loss: 0.0091 - val_tf_op_layer_mul_1_loss: 44.1427 - val_tf_op_layer_mul_loss: 34.1416 - val_tf_op_layer_mul_2_loss: 33.8234 - val_tf_op_layer_mul_3_loss: 3.7208 - val_tf_op_layer_mul_4_loss: 6.6251 - val_tf_op_layer_mul_5_loss: 0.4502 - val_tf_op_layer_mul_6_loss: 0.1756 - val_tf_op_layer_mul_7_loss: 80.4636 - val_tf_op_layer_mul_8_loss: 18.1947 - val_tf_op_layer_rot_row_product_loss: 0.0000e+00 - val_tf_op_layer_determinant_loss: 9.9715e-09 - val_tf_op_layer_rot_identity_loss: 0.0391 - 305s/epoch - 7ms/sample
