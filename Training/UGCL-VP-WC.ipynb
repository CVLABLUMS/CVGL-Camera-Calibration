# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
tf.set_random_seed(1)
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.compat.v1.Session(config=config)
import matplotlib.pyplot as plt
import PIL.Image as Image
import math
import numpy as np
import tensorflow.keras.backend as K
from tensorflow.keras.utils import plot_model
import json
from tensorflow.keras.losses import mse
import os
import glob
import random
#import cv2
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.inception_v3 import InceptionV3
import datetime
from tensorflow.keras.layers import Dense, Input, concatenate, Conv2D, MaxPooling2D, Flatten, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger, ReduceLROnPlateau
from tensorflow.keras.callbacks import TensorBoard
# %matplotlib inline

from tensorflow.keras.losses import Loss
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def add_layer(tensor):
    return tensor[0] + tensor[1]

def mul_layer(tensor):
    return tensor[0] * tensor[1]

def div_layer(tensor):
    return tensor[0] / tensor[1]

def sub_layer(tensor):
    return tensor[0] - tensor[1]

def neg_layer(tensor):
    return -tensor

def cos_layer(tensor):
    return tf.math.cos(tensor)

def sin_layer(tensor):
    return tf.math.sin(tensor)

# %%
# feature extraction from left image

left_img = Input(shape = (150,150,3), name="left_image")

# feature extraction from right image
right_img = Input(shape = (150,150,3), name="right_image")

left_phi_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=left_img, input_shape=(150,150,3))
for layer in left_phi_model.layers:
  layer._name = layer._name+"f1_base"

left_phi_features = left_phi_model.output
left_flat = Flatten(name='left-phi-flattened')(left_phi_features)

right_phi_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=right_img, input_shape=(150,150,3))
for layer in right_phi_model.layers:
  layer._name = layer._name+"f2_base"

right_phi_features = right_phi_model.output
right_flat = Flatten(name='right-phi-flattened')(right_phi_features)

concat = concatenate([left_flat, right_flat])

# fx
dense_1 = Dense(120, activation = 'relu')(concat)
dense_2 = Dense(84, activation = 'relu')(dense_1)
pred_fx = Dense(1, name='fx')(dense_2)

# fy
dense_3 = Dense(120, activation = 'relu')(concat)
dense_4 = Dense(84, activation = 'relu')(dense_3)
pred_fy = Dense(1, name='fy')(dense_4)

# u0
dense_5 = Dense(120, activation = 'relu')(concat)
dense_6 = Dense(84, activation = 'relu')(dense_5)
pred_u0 = Dense(1, name='u0')(dense_6)

# v0
dense_7 = Dense(120, activation = 'relu')(concat)
dense_8 = Dense(84, activation = 'relu')(dense_7)
pred_v0 = Dense(1, name='v0')(dense_8)

# baseline
dense_9 = Dense(120, activation = 'relu')(concat)
dense_10 = Dense(84, activation = 'relu')(dense_9)
pred_baseline = Dense(1, name='baseline')(dense_10)

# tx
dense_11 = Dense(120, activation = 'relu')(concat)
dense_12 = Dense(84, activation = 'relu')(dense_11)
pred_x = Dense(1, name='x')(dense_12)

# ty
dense_13 = Dense(120, activation = 'relu')(concat)
dense_14 = Dense(84, activation = 'relu')(dense_13)
pred_y = Dense(1, name='y')(dense_14)

# tz
dense_15 = Dense(120, activation = 'relu')(concat)
dense_16 = Dense(84, activation = 'relu')(dense_15)
pred_z = Dense(1, name='z')(dense_16)

# pitch
dense_17 = Dense(120, activation = 'relu')(concat)
dense_18 = Dense(84, activation = 'relu')(dense_17)
pred_pitch = Dense(1, name='pitch')(dense_18)

# u
dense_19 = Dense(120, activation = 'relu')(concat)
dense_20 = Dense(84, activation = 'relu')(dense_19)
pred_u = Dense(1, name='u')(dense_20)

# v
dense_21 = Dense(120, activation = 'relu')(concat)
dense_22 = Dense(84, activation = 'relu')(dense_21)
pred_v = Dense(1, name='v')(dense_22)

# disparity
dense_23 = Dense(120, activation = 'relu')(concat)
dense_24 = Dense(84, activation = 'relu')(dense_23)
pred_disparity = Dense(1, name='disparity')(dense_24)


# w_xworld: alpha for X 3D point
dense_31 = Dense(120, activation = 'relu')(concat)
dense_32 = Dense(84, activation = 'relu')(dense_31)
w_xworld = Dense(1, name='w_xworld', activation = 'sigmoid')(dense_32)

# w_yworld: alpha for Y 3D point
dense_33 = Dense(120, activation = 'relu')(concat)
dense_34 = Dense(84, activation = 'relu')(dense_33)
w_yworld = Dense(1, name='w_yworld', activation = 'sigmoid')(dense_34)

# w_zworld: alpha for Z 3D point
dense_35 = Dense(120, activation = 'relu')(concat)
dense_36 = Dense(84, activation = 'relu')(dense_35)
w_zworld = Dense(1, name='w_zworld', activation = 'sigmoid')(dense_36)

#vp+_+ is for vanishing points

# alpha_vp1_1
dense_vp1_1_1 = Dense(120, activation = 'relu')(concat)
dense_vp1_1_2 = Dense(84, activation = 'relu')(dense_vp1_1_1)
alpha_vp1_1 = Dense(1, name='alpha_vp1_1', activation = 'sigmoid')(dense_vp1_1_2)

# alpha_vp1_2
dense_vp1_2_1 = Dense(120, activation = 'relu')(concat)
dense_vp1_2_2 = Dense(84, activation = 'relu')(dense_vp1_2_1)
alpha_vp1_2 = Dense(1, name='alpha_vp1_2', activation = 'sigmoid')(dense_vp1_2_2)

# alpha_vp2_1
dense_vp2_1_1 = Dense(120, activation = 'relu')(concat)
dense_vp2_1_2 = Dense(84, activation = 'relu')(dense_vp2_1_1)
alpha_vp2_1 = Dense(1, name='alpha_vp2_1', activation = 'sigmoid')(dense_vp2_1_2)

# alpha_vp2_2
dense_vp2_2_1 = Dense(120, activation = 'relu')(concat)
dense_vp2_2_2 = Dense(84, activation = 'relu')(dense_vp2_2_1)
alpha_vp2_2 = Dense(1, name='alpha_vp2_2', activation = 'sigmoid')(dense_vp2_2_2)

#wc+_+ is for word center

# alpha_wc1_1
dense_wc1_1_1 = Dense(120, activation = 'relu')(concat)
dense_wc1_1_2 = Dense(84, activation = 'relu')(dense_wc1_1_1)
alpha_wc1_1 = Dense(1, name='alpha_wc1_1', activation = 'sigmoid')(dense_wc1_1_2)

# alpha_wc1_2
dense_wc1_2_1 = Dense(120, activation = 'relu')(concat)
dense_wc1_2_2 = Dense(84, activation = 'relu')(dense_wc1_2_1)
alpha_wc1_2 = Dense(1, name='alpha_wc1_2', activation = 'sigmoid')(dense_wc1_2_2)

# alpha_con: alpha for all the constraints
dense_con1 = Dense(120, activation = 'relu')(concat)
dense_con2 = Dense(84, activation = 'relu')(dense_con1)
alpha_con = Dense(1, name='alpha_con', activation = 'sigmoid')(dense_con2)

# alpha_3d: alpha for all the 3d points
dense_3d1 = Dense(120, activation = 'relu')(concat)
dense_3d2 = Dense(84, activation = 'relu')(dense_3d1)
alpha_3d = Dense(1, name='alpha_3d', activation = 'sigmoid')(dense_3d2)

# For 3D point:

# xCam = (self.intrinsic.fx * self.extrinsic.baseline) / disparity
mul_1 = Lambda(mul_layer)([pred_fx, pred_baseline])
xCam = Lambda(div_layer)([mul_1, pred_disparity])

# yCam = - (xCam / self.intrinsic.fx) * (u - self.intrinsic.u0)
div_1 = Lambda(div_layer)([xCam, pred_fx])
sub_1 = Lambda(sub_layer)([pred_u, pred_u0])
yCam = Lambda(mul_layer)([Lambda(neg_layer)(div_1), sub_1])

# zCam = (xCam / self.intrinsic.fy) * (self.intrinsic.v0 - v)
div_2 = Lambda(div_layer)([xCam, pred_fy])
sub_2 = Lambda(sub_layer)([pred_v0, pred_v])
zCam = Lambda(mul_layer)([div_2, sub_2])

# Y = yCam + self.extrinsic.y
pred_yWorld = Lambda(add_layer)([yCam, pred_y])
pred_yWorld = Lambda(mul_layer, name='yWorld')([pred_yWorld, w_yworld]) * alpha_3d

# X = xCam * math.cos(self.extrinsic.pitch) + zCam * math.sin(self.extrinsic.pitch) + self.extrinsic.x
mul_2 = Lambda(mul_layer)([xCam, Lambda(cos_layer)(pred_pitch)])
mul_3 = Lambda(mul_layer)([zCam, Lambda(sin_layer)(pred_pitch)])
add_1 = Lambda(add_layer)([mul_2, mul_3])
pred_xWorld = Lambda(add_layer)([add_1, pred_x])
pred_xWorld = Lambda(mul_layer, name='xWorld')([pred_xWorld, w_xworld]) * alpha_3d

# Z = - xCam * math.sin(self.extrinsic.pitch) + zCam * math.cos(self.extrinsic.pitch) + self.extrinsic.z
mul_4 = Lambda(mul_layer)([Lambda(neg_layer)(xCam), Lambda(sin_layer)(pred_pitch)])
mul_5 = Lambda(mul_layer)([zCam, Lambda(cos_layer)(pred_pitch)])
add_2 = Lambda(add_layer)([mul_4, mul_5])
pred_zWorld = Lambda(add_layer)([add_2, pred_z])
pred_zWorld = Lambda(mul_layer, name='zWorld')([pred_zWorld, w_zworld]) * alpha_3d

# For Constraints

dim = tf.shape(pred_fx)[0]

k_00 = pred_fx
k_02 = pred_u0
k_11 = pred_fy
k_12 = pred_v0

# k = intrinsic matrix

k = tf.stack([
    tf.stack([k_00, tf.zeros((dim, 1), dtype=tf.float32), k_02], axis=1),
    tf.stack([tf.zeros((dim, 1), dtype=tf.float32), k_11, k_12], axis=1),
    tf.stack([tf.zeros((dim, 1), dtype=tf.float32), tf.zeros((dim, 1), dtype=tf.float32), tf.ones((dim, 1), dtype=tf.float32)], axis=1)
], axis=2)

k = tf.reshape(tf.transpose(tf.reshape(k, (dim, 3, 3)), perm=[0, 2, 1]), (dim, 3, 3))


r_pitch = tf.stack([
    tf.stack([tf.cos(pred_pitch), tf.zeros(shape=(dim, 1), dtype=tf.float32), tf.sin(pred_pitch)], axis=1),
    tf.stack([tf.zeros(shape=(dim, 1), dtype=tf.float32), tf.ones(shape=(dim, 1), dtype=tf.float32), tf.zeros(shape=(dim, 1), dtype=tf.float32)], axis=1),
    tf.stack([-tf.sin(pred_pitch), tf.zeros(shape=(dim, 1), dtype=tf.float32), tf.cos(pred_pitch)], axis=1)
], axis=2)


r_pitch = tf.reshape(tf.transpose(tf.reshape(r_pitch, (dim, 3, 3)), perm=[0, 2, 1]), (dim, 3, 3))

# t = translation
t = tf.stack([pred_x, pred_y, pred_z], axis=1)

# r = rotation + t
r = tf.concat([r_pitch, t], axis=2)



# projection matrix
p = tf.linalg.matmul(k, r) + 1

vanish_point_1 = tf.gather(p, [0, 2, 3], axis=2)

vp1_1 = Lambda(mul_layer, name='vp1_1')([
    alpha_vp1_1,
    vanish_point_1[:, :, 0][:, 0:1] / ((vanish_point_1[:, :, 0][:, 2:3] + 0.00001) + 0.00001)
]) * alpha_con

vp1_2 = Lambda(mul_layer, name='vp1_2')([
    alpha_vp1_2,
    vanish_point_1[:, :, 0][:, 1:2] / ((vanish_point_1[:, :, 0][:, 2:3] + 0.00001) + 0.00001)
]) * alpha_con

vp2_1 = Lambda(mul_layer, name='vp2_1')([
    alpha_vp2_1,
    vanish_point_1[:, :, 1][:, 0:1] / ((vanish_point_1[:, :, 1][:, 2:3] + 0.00001) + 0.00001)
]) * alpha_con

vp2_2 = Lambda(mul_layer, name='vp2_2')([
    alpha_vp2_2,
    vanish_point_1[:, :, 1][:, 1:2] / ((vanish_point_1[:, :, 1][:, 2:3] + 0.00001) + 0.00001)
]) * alpha_con

wc1_1 = Lambda(mul_layer, name='wc1_1')([
    alpha_wc1_1,
    vanish_point_1[:, :, 2][:, 1:2] / ((vanish_point_1[:, :, 2][:, 2:3] + 0.00001) + 0.00001)
]) * alpha_con

wc1_2 = Lambda(mul_layer, name='wc1_2')([
    alpha_wc1_2,
    vanish_point_1[:, :, 2][:, 1:2] / ((vanish_point_1[:, :, 2][:, 2:3] + 0.00001) + 0.00001)
]) * alpha_con

# create model
model = Model(inputs=[left_img, right_img], outputs=[pred_fx, pred_fy, pred_u0, pred_v0, pred_baseline, pred_disparity, pred_x, pred_y, pred_z, pred_pitch, pred_xWorld,pred_yWorld,pred_zWorld, vp1_1, vp1_2, vp2_1, vp2_2, wc1_1, wc1_2])

# set output types
target1 = tf.placeholder(dtype='float32', shape=(1,1))
target2 = tf.placeholder(dtype='float32', shape=(1,1))
target3 = tf.placeholder(dtype='float32', shape=(1,1))
target4 = tf.placeholder(dtype='float32', shape=(1,1))
target5 = tf.placeholder(dtype='float32', shape=(1,1))
target6 = tf.placeholder(dtype='float32', shape=(1,1))
target7 = tf.placeholder(dtype='float32', shape=(1,1))
target8 = tf.placeholder(dtype='float32', shape=(1,1))
target9 = tf.placeholder(dtype='float32', shape=(1,1))
target10 = tf.placeholder(dtype='float32', shape=(1,1))
target11 = tf.placeholder(dtype='float32', shape=(1,1))
target12 = tf.placeholder(dtype='float32', shape=(1,1))
target13 = tf.placeholder(dtype='float32', shape=(1,1))

t_vp1_1 = tf.placeholder(dtype='float32', shape=(1,1))
t_vp1_2 = tf.placeholder(dtype='float32', shape=(1,1))
t_vp2_1 = tf.placeholder(dtype='float32', shape=(1,1))
t_vp2_2 = tf.placeholder(dtype='float32', shape=(1,1))
t_wc1_1 = tf.placeholder(dtype='float32', shape=(1,1))
t_wc1_2 = tf.placeholder(dtype='float32', shape=(1,1))


learning_rate = 0.001

# compile model
model.compile(loss="mae", target_tensors=[target1, target2, target3, target4, target5, target6, target7, target8, target9, target10, target11, target12, target13, t_vp1_1, t_vp1_2, t_vp2_1, t_vp2_2, t_wc1_1, t_wc1_2], optimizer=optimizers.legacy.Adam(lr=learning_rate));
#plot_model(model, to_file='model.png')

# %%
import numpy as np
data_path = 'your pth/'
Fx = np.load(data_path+"fx.npy", mmap_mode='r')
Fy = np.load(data_path+"fy.npy", mmap_mode='r')
U0 = np.load(data_path+"U0.npy", mmap_mode='r')
V0 = np.load(data_path+"V0.npy", mmap_mode='r')
Disparity = np.load(data_path+"disparity.npy", mmap_mode='r')
Tx = np.load(data_path+"x.npy", mmap_mode='r')
Ty = np.load(data_path+"y.npy", mmap_mode='r') 
Tz = np.load(data_path+"z.npy", mmap_mode='r')
Baseline = np.load(data_path+"baseline.npy", mmap_mode='r')
Pitch = np.load(data_path+"pitch.npy", mmap_mode='r')
X = np.load(data_path+"xworld.npy", mmap_mode='r')
Y = np.load(data_path+"yworld.npy", mmap_mode='r')
Z = np.load(data_path+"zworld.npy", mmap_mode='r')
Left_images = np.load(data_path+"left_img.npy", mmap_mode='r')
Right_images = np.load(data_path+"right_img.npy", mmap_mode='r')

# %%
# Getting Vanishing points, World Center & rotation matrix constraints for the training.

train_num = int(len(Fx)*0.7)#- 40000

pred_fx = np.array(Fx[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_fy = np.array(Fy[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_pitch = np.array(Pitch[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_x = np.array(Tx[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_y = np.array(Ty[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_z = np.array(Tz[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_u0 = np.array(U0[0:train_num]).reshape(train_num, 1).astype(np.float32)
pred_v0 = np.array(V0[0:train_num]).reshape(train_num, 1).astype(np.float32)

dim = pred_fx.shape[0]

k_00 = pred_fx
k_02 = pred_u0
k_11 = pred_fy
k_12 = pred_v0

k = np.stack([
    np.stack([k_00, np.zeros((dim, 1), dtype=np.float32), k_02], axis=1),
    np.stack([np.zeros((dim, 1), dtype=np.float32), k_11, k_12], axis=1),
    np.stack([np.zeros((dim, 1), dtype=np.float32), np.zeros((dim, 1), dtype=np.float32), np.ones((dim, 1), dtype=np.float32)], axis=1)
], axis=2)

k = np.reshape(np.transpose(np.reshape(k, (dim, 3, 3), order='F'), (0, 2, 1)), (dim, 3, 3))

pred_pitch= np.stack([
    np.stack([np.cos(pred_pitch), np.zeros((dim, 1), dtype=np.float32), np.sin(pred_pitch)], axis=1),
    np.stack([np.zeros((dim, 1), dtype=np.float32), np.ones((dim, 1), dtype=np.float32), np.zeros((dim, 1), dtype=np.float32)], axis=1),
    np.stack([-np.sin(pred_pitch), np.zeros((dim, 1), dtype=np.float32), np.cos(pred_pitch)], axis=1)
], axis=2)

pred_pitch = np.reshape(np.transpose(np.reshape(pred_pitch, (dim, 3, 3), order='F'), (0, 2, 1)), (dim, 3, 3))

t = np.stack([pred_x, pred_y, pred_z], axis=1)

r = pred_pitch
r = np.concatenate([r, t], axis=2) 

# Projection matrix
p = np.matmul(k, r) + 1

vanish_point_1 =  p[:, :, [0, 2, 3]]
               

train_vp1_1 = vanish_point_1[:, :, 0][:, 0:1]/vanish_point_1[:, :, 0][:, 2:3]
train_vp1_2 = vanish_point_1[:, :, 0][:, 1:2]/vanish_point_1[:, :, 0][:, 2:3]
train_vp2_1 = vanish_point_1[:, :, 1][:, 0:1]/vanish_point_1[:, :, 1][:, 2:3]
train_vp2_2 = vanish_point_1[:, :, 1][:, 1:2]/vanish_point_1[:, :, 1][:, 2:3]
train_wc_1_1 = vanish_point_1[:, :, 2][:, 0:1]/vanish_point_1[:, :, 2][:, 2:3]
train_wc_1_2 = vanish_point_1[:, :, 2][:, 1:2]/vanish_point_1[:, :, 2][:, 2:3]

# %%
# Getting Vanishing points, World Center & rotation matrix constraints for the validation.

train_num = int(len(Fx)*0.7)
valid_reshape = int(len(Fx)) -  int(len(Fx)*0.7)

pred_fx = np.array(Fx[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_fy = np.array(Fy[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_pitch = np.array(Pitch[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_x = np.array(Tx[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_y = np.array(Ty[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_z = np.array(Tz[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_u0 = np.array(U0[train_num:]).reshape(valid_reshape, 1).astype(np.float32)
pred_v0 = np.array(V0[train_num:]).reshape(valid_reshape, 1).astype(np.float32)

dim = pred_fx.shape[0]

k_00 = pred_fx
k_02 = pred_u0
k_11 = pred_fy
k_12 = pred_v0

k = np.stack([
    np.stack([k_00, np.zeros((dim, 1), dtype=np.float32), k_02], axis=1),
    np.stack([np.zeros((dim, 1), dtype=np.float32), k_11, k_12], axis=1),
    np.stack([np.zeros((dim, 1), dtype=np.float32), np.zeros((dim, 1), dtype=np.float32), np.ones((dim, 1), dtype=np.float32)], axis=1)
], axis=2)

k = np.reshape(np.transpose(np.reshape(k, (dim, 3, 3), order='F'), (0, 2, 1)), (dim, 3, 3))

pred_pitch= np.stack([
    np.stack([np.cos(pred_pitch), np.zeros((dim, 1), dtype=np.float32), np.sin(pred_pitch)], axis=1),
    np.stack([np.zeros((dim, 1), dtype=np.float32), np.ones((dim, 1), dtype=np.float32), np.zeros((dim, 1), dtype=np.float32)], axis=1),
    np.stack([-np.sin(pred_pitch), np.zeros((dim, 1), dtype=np.float32), np.cos(pred_pitch)], axis=1)
], axis=2)

pred_pitch = np.reshape(np.transpose(np.reshape(pred_pitch, (dim, 3, 3), order='F'), (0, 2, 1)), (dim, 3, 3))

t = np.stack([pred_x, pred_y, pred_z], axis=1)

r = np.concatenate([pred_pitch, t], axis=2)

# Projection matrix
p = np.matmul(k, r) + 1


vanish_point_1 =  p[:, :, [0, 2, 3]]

test_vp1_1 = vanish_point_1[:, :, 0][:, 0:1]/vanish_point_1[:, :, 0][:, 2:3]
test_vp1_2 = vanish_point_1[:, :, 0][:, 1:2]/vanish_point_1[:, :, 0][:, 2:3]
test_vp2_1 = vanish_point_1[:, :, 1][:, 0:1]/vanish_point_1[:, :, 1][:, 2:3]
test_vp2_2 = vanish_point_1[:, :, 1][:, 1:2]/vanish_point_1[:, :, 1][:, 2:3]
test_wc_1_1 = vanish_point_1[:, :, 2][:, 0:1]/vanish_point_1[:, :, 2][:, 2:3]
test_wc_1_2 = vanish_point_1[:, :, 2][:, 1:2]/vanish_point_1[:, :, 2][:, 2:3]

# %%
import os
from tensorflow.keras.callbacks import TensorBoard, LearningRateScheduler
from keras.applications.inception_v3 import InceptionV3
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Model
from keras.layers import Dense, Flatten, Input
#from utils_regressor_focal_dist import RotNetDataGenerator, angle_error, CustomModelCheckpoint
from keras import optimizers
import numpy as np
import glob, math
from shutil import copyfile
import datetime, random
import tensorflow as tf
#from keras.backend.tensorflow_backend import set_session

model_name = 'model_multi_class/'
SAVE = "UGCL_VP_WC/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + '/'
# Save
output_folder = SAVE + model_name
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

output_log = output_folder + "Log/"
if not os.path.exists(output_log):
    os.makedirs(output_log)

output_weight = output_folder + "Best/"
if not os.path.exists(output_weight):
    os.makedirs(output_weight)


input_shape = (112, 112, 3)

tensorboard = TensorBoard(log_dir=output_log)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto', restore_best_weights=True)

csv_logger = CSVLogger('UGCL_VP_WC.log')


checkpointer = tf.keras.callbacks.ModelCheckpoint(
    filepath=output_weight + "weights_{epoch:02d}_{val_loss}.h5",
    monitor="val_loss",
    verbose=0,
    save_best_only=True,
    save_weights_only=True
)

history = model.fit(
    x=[Left_images[:int(len(Left_images)*0.7)], Right_images[:int(len(Left_images)*0.7)]],
    y=[Fx[:int(len(Left_images)*0.7)], Fy[:int(len(Left_images)*0.7)], U0[:int(len(Left_images)*0.7)], V0[:int(len(Left_images)*0.7)], Baseline[:int(len(Left_images)*0.7)], Disparity[:int(len(Left_images)*0.7)], Tx[:int(len(Left_images)*0.7)], Ty[:int(len(Left_images)*0.7)], Tz[:int(len(Left_images)*0.7)], Pitch[:int(len(Left_images)*0.7)], X[:int(len(Left_images)*0.7)], Y[:int(len(Left_images)*0.7)], Z[:int(len(Left_images)*0.7)], train_vp1_1, train_vp1_2, train_vp2_1, train_vp2_2, train_wc_1_1, train_wc_1_2],
    batch_size=32,
    epochs=100,
    verbose=2,
    shuffle=True,
    initial_epoch=0,
    validation_data=([Left_images[int(len(Left_images)*0.7):], Right_images[int(len(Left_images)*0.7):]], [Fx[int(len(Left_images)*0.7):], Fy[int(len(Left_images)*0.7):], U0[int(len(Left_images)*0.7):], V0[int(len(Left_images)*0.7):], Baseline[int(len(Left_images)*0.7):], Disparity[int(len(Left_images)*0.7):], Tx[int(len(Left_images)*0.7):], Ty[int(len(Left_images)*0.7):], Tz[int(len(Left_images)*0.7):], Pitch[int(len(Left_images)*0.7):], X[int(len(Left_images)*0.7):], Y[int(len(Left_images)*0.7):], Z[int(len(Left_images)*0.7):], test_vp1_1, test_vp1_2, test_vp2_1, test_vp2_2, test_wc_1_1, test_wc_1_2]),
    callbacks=[tensorboard, checkpointer, csv_logger]
)
# Out:
# Train on 44520 samples, validate on 19080 samples
# Epoch 1/100
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
#
- val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4551 - val_tf_op_layer_mul_8_loss: 34.9884 - 308s/epoch - 7ms/sample
# Epoch 3/100
# 44520/44520 - 304s - loss: 410.6126 - fx_loss: 5.9976 - fy_loss: 6.0392 - u0_loss: 0.8536 - v0_loss: 0.8929 - baseline_loss: 0.1526 - disparity_loss: 2.9508 - x_loss: 0.2004 - y_loss: 0.1290 - z_loss: 0.1373 - pitch_loss: 0.0424 - tf_op_layer_mul_1_loss: 39.2721 - tf_op_layer_mul_loss: 30.8477 - tf_op_layer_mul_2_loss: 30.4703 - tf_op_layer_mul_3_loss: 95.3081 - tf_op_layer_mul_4_loss: 6.5563 - tf_op_layer_mul_5_loss: 37.8967 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2910 - tf_op_layer_mul_8_loss: 34.6722 - val_loss: 431.6221 - val_fx_loss: 10.1128 - val_fy_loss: 10.0922 - val_u0_loss: 1.4032 - val_v0_loss: 0.7492 - val_baseline_loss: 0.1508 - val_disparity_loss: 2.8808 - val_x_loss: 0.2003 - val_y_loss: 0.1262 - val_z_loss: 0.1468 - val_pitch_loss: 0.0368 - val_tf_op_layer_mul_1_loss: 44.1336 - val_tf_op_layer_mul_loss: 34.1307 - val_tf_op_layer_mul_2_loss: 33.8129 - val_tf_op_layer_mul_3_loss: 95.6526 - val_tf_op_layer_mul_4_loss: 6.6223 - val_tf_op_layer_mul_5_loss: 37.8878 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4867 - val_tf_op_layer_mul_8_loss: 34.9878 - 304s/epoch - 7ms/sample
# Epoch 4/100
# 44520/44520 - 301s - loss: 409.3944 - fx_loss: 5.5432 - fy_loss: 5.5760 - u0_loss: 0.7566 - v0_loss: 0.8089 - baseline_loss: 0.1477 - disparity_loss: 2.8492 - x_loss: 0.2004 - y_loss: 0.1262 - z_loss: 0.1302 - pitch_loss: 0.0395 - tf_op_layer_mul_1_loss: 39.2555 - tf_op_layer_mul_loss: 30.8364 - tf_op_layer_mul_2_loss: 30.4608 - tf_op_layer_mul_3_loss: 95.3095 - tf_op_layer_mul_4_loss: 6.5560 - tf_op_layer_mul_5_loss: 37.8956 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2920 - tf_op_layer_mul_8_loss: 34.6769 - val_loss: 424.8593 - val_fx_loss: 6.3905 - val_fy_loss: 6.4263 - val_u0_loss: 0.9117 - val_v0_loss: 1.7052 - val_baseline_loss: 0.1429 - val_disparity_loss: 3.0289 - val_x_loss: 0.2003 - val_y_loss: 0.1249 - val_z_loss: 0.1256 - val_pitch_loss: 0.0864 - val_tf_op_layer_mul_1_loss: 44.1844 - val_tf_op_layer_mul_loss: 34.1755 - val_tf_op_layer_mul_2_loss: 33.8617 - val_tf_op_layer_mul_3_loss: 95.6745 - val_tf_op_layer_mul_4_loss: 6.6235 - val_tf_op_layer_mul_5_loss: 37.8893 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4945 - val_tf_op_layer_mul_8_loss: 34.9879 - 301s/epoch - 7ms/sample
# Epoch 5/100
tf_op_layer_mul_loss: 34.2549 - val_tf_op_layer_mul_2_loss: 33.9429 - val_tf_op_layer_mul_3_loss: 95.6718 - val_tf_op_layer_mul_4_loss: 6.6196 - val_tf_op_layer_mul_5_loss: 37.8890 - val_tf_op_layer_mul_6_loss: 37.9050 - val_tf_op_layer_mul_7_loss: 80.5205 - val_tf_op_layer_mul_8_loss: 34.9916 - 300s/epoch - 7ms/sample
# Epoch 12/100
# 44520/44520 - 301s - loss: 406.1918 - fx_loss: 4.2166 - fy_loss: 4.2458 - u0_loss: 0.3046 - v0_loss: 0.3460 - baseline_loss: 0.1440 - disparity_loss: 3.2284 - x_loss: 0.2004 - y_loss: 0.1254 - z_loss: 0.1252 - pitch_loss: 0.0397 - tf_op_layer_mul_1_loss: 39.3037 - tf_op_layer_mul_loss: 30.8632 - tf_op_layer_mul_2_loss: 30.4865 - tf_op_layer_mul_3_loss: 95.3051 - tf_op_layer_mul_4_loss: 6.5557 - tf_op_layer_mul_5_loss: 37.8958 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2834 - tf_op_layer_mul_8_loss: 34.6680 - val_loss: 429.6140 - val_fx_loss: 9.4129 - val_fy_loss: 9.4651 - val_u0_loss: 0.6653 - val_v0_loss: 0.5544 - val_baseline_loss: 0.1427 - val_disparity_loss: 3.1770 - val_x_loss: 0.2004 - val_y_loss: 0.1248 - val_z_loss: 0.1249 - val_pitch_loss: 0.0350 - val_tf_op_layer_mul_1_loss: 44.1424 - val_tf_op_layer_mul_loss: 34.1352 - val_tf_op_layer_mul_2_loss: 33.8180 - val_tf_op_layer_mul_3_loss: 95.6568 - val_tf_op_layer_mul_4_loss: 6.6215 - val_tf_op_layer_mul_5_loss: 37.8847 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4906 - val_tf_op_layer_mul_8_loss: 34.9767 - 301s/epoch - 7ms/sample
# Epoch 13/100
# 44520/44520 - 300s - loss: 405.8629 - fx_loss: 3.9637 - fy_loss: 3.9954 - u0_loss: 0.2943 - v0_loss: 0.3495 - baseline_loss: 0.1440 - disparity_loss: 3.4063 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0463 - tf_op_layer_mul_1_loss: 39.2591 - tf_op_layer_mul_loss: 30.8418 - tf_op_layer_mul_2_loss: 30.4659 - tf_op_layer_mul_3_loss: 95.3020 - tf_op_layer_mul_4_loss: 6.5564 - tf_op_layer_mul_5_loss: 37.8971 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2855 - tf_op_layer_mul_8_loss: 34.6699 - val_loss: 461.6110 - val_fx_loss: 13.3092 - val_fy_loss: 14.2981 - val_u0_loss: 11.0875 - val_v0_loss: 11.7997 - val_baseline_loss: 0.2361 - val_disparity_loss: 4.0841 - val_x_loss: 0.2038 - val_y_loss: 0.3523 - val_z_loss: 0.4116 - val_pitch_loss: 0.0879 - val_tf_op_layer_mul_1_loss: 44.1334 - val_tf_op_layer_mul_loss: 34.1317 - val_tf_op_layer_mul_2_loss: 33.8144 - val_tf_op_layer_mul_3_loss: 95.6546 - val_tf_op_layer_mul_4_loss: 6.6232 - val_tf_op_layer_mul_5_loss: 37.8844 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.
- tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.3031 - tf_op_layer_mul_8_loss: 34.6755 - val_loss: 421.2718 - val_fx_loss: 4.5888 - val_fy_loss: 4.5887 - val_u0_loss: 1.2739 - val_v0_loss: 0.9182 - val_baseline_loss: 0.1520 - val_disparity_loss: 3.5277 - val_x_loss: 0.2002 - val_y_loss: 0.1260 - val_z_loss: 0.1293 - val_pitch_loss: 0.0503 - val_tf_op_layer_mul_1_loss: 44.1399 - val_tf_op_layer_mul_loss: 34.1313 - val_tf_op_layer_mul_2_loss: 33.8128 - val_tf_op_layer_mul_3_loss: 95.6714 - val_tf_op_layer_mul_4_loss: 6.6202 - val_tf_op_layer_mul_5_loss: 37.8897 - val_tf_op_layer_mul_6_loss: 37.9050 - val_tf_op_layer_mul_7_loss: 80.4936 - val_tf_op_layer_mul_8_loss: 34.9904 - 300s/epoch - 7ms/sample
# Epoch 17/100
# 44520/44520 - 299s - loss: 403.7293 - fx_loss: 3.1667 - fy_loss: 3.2103 - u0_loss: 0.2505 - v0_loss: 0.2976 - baseline_loss: 0.1441 - disparity_loss: 2.9658 - x_loss: 0.2004 - y_loss: 0.1254 - z_loss: 0.1251 - pitch_loss: 0.0318 - tf_op_layer_mul_1_loss: 39.2540 - tf_op_layer_mul_loss: 30.8372 - tf_op_layer_mul_2_loss: 30.4610 - tf_op_layer_mul_3_loss: 95.2957 - tf_op_layer_mul_4_loss: 6.5560 - tf_op_layer_mul_5_loss: 37.8970 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2875 - tf_op_layer_mul_8_loss: 34.6757 - val_loss: 422.2649 - val_fx_loss: 5.8849 - val_fy_loss: 5.7360 - val_u0_loss: 0.4789 - val_v0_loss: 0.5604 - val_baseline_loss: 0.1559 - val_disparity_loss: 3.2414 - val_x_loss: 0.2000 - val_y_loss: 0.1261 - val_z_loss: 0.1253 - val_pitch_loss: 0.0415 - val_tf_op_layer_mul_1_loss: 44.1348 - val_tf_op_layer_mul_loss: 34.1333 - val_tf_op_layer_mul_2_loss: 33.8148 - val_tf_op_layer_mul_3_loss: 95.6367 - val_tf_op_layer_mul_4_loss: 6.6227 - val_tf_op_layer_mul_5_loss: 37.8899 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4596 - val_tf_op_layer_mul_8_loss: 34.9714 - 299s/epoch - 7ms/sample
# Epoch 18/100
# 44520/44520 - 300s - loss: 402.9767 - fx_loss: 2.8093 - fy_loss: 2.8371 - u0_loss: 0.2665 - v0_loss: 0.2646 - baseline_loss: 0.1440 - disparity_loss: 2.9646 - x_loss: 0.2005 - y_loss: 0.1255 - z_loss: 0.1251 - pitch_loss: 0.0313 - tf_op_layer_mul_1_loss: 39.2819 - tf_op_layer_mul_loss: 30.8489 - tf_op_layer_mul_2_loss: 30.4747 - tf_op_layer_mul_3_loss: 95.3107 - tf_op_layer_mul_4_loss: 6.5565 - tf_op_layer_mul_5_loss: 37.8962 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.
- tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.3046 - tf_op_layer_mul_8_loss: 34.6712 - val_loss: 430.0996 - val_fx_loss: 10.2544 - val_fy_loss: 10.3549 - val_u0_loss: 0.1409 - val_v0_loss: 0.1718 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.8355 - val_x_loss: 0.2002 - val_y_loss: 0.1254 - val_z_loss: 0.1250 - val_pitch_loss: 0.0255 - val_tf_op_layer_mul_1_loss: 44.1308 - val_tf_op_layer_mul_loss: 34.1310 - val_tf_op_layer_mul_2_loss: 33.8133 - val_tf_op_layer_mul_3_loss: 95.6418 - val_tf_op_layer_mul_4_loss: 6.6230 - val_tf_op_layer_mul_5_loss: 37.8876 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4464 - val_tf_op_layer_mul_8_loss: 34.9639 - 300s/epoch - 7ms/sample
# Epoch 26/100
# 44520/44520 - 303s - loss: 401.0581 - fx_loss: 2.1098 - fy_loss: 2.1419 - u0_loss: 0.2072 - v0_loss: 0.2509 - baseline_loss: 0.1440 - disparity_loss: 2.5107 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0258 - tf_op_layer_mul_1_loss: 39.2545 - tf_op_layer_mul_loss: 30.8368 - tf_op_layer_mul_2_loss: 30.4604 - tf_op_layer_mul_3_loss: 95.2970 - tf_op_layer_mul_4_loss: 6.5577 - tf_op_layer_mul_5_loss: 37.8967 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2798 - tf_op_layer_mul_8_loss: 34.6702 - val_loss: 415.3074 - val_fx_loss: 2.9600 - val_fy_loss: 3.0323 - val_u0_loss: 0.1878 - val_v0_loss: 0.0740 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.7198 - val_x_loss: 0.2000 - val_y_loss: 0.1248 - val_z_loss: 0.1251 - val_pitch_loss: 0.0236 - val_tf_op_layer_mul_1_loss: 44.1334 - val_tf_op_layer_mul_loss: 34.1315 - val_tf_op_layer_mul_2_loss: 33.8123 - val_tf_op_layer_mul_3_loss: 95.6398 - val_tf_op_layer_mul_4_loss: 6.6251 - val_tf_op_layer_mul_5_loss: 37.8915 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4529 - val_tf_op_layer_mul_8_loss: 34.9733 - 303s/epoch - 7ms/sample
# Epoch 27/100
# 44520/44520 - 303s - loss: 400.8136 - fx_loss: 2.0237 - fy_loss: 2.0576 - u0_loss: 0.2205 - v0_loss: 0.2332 - baseline_loss: 0.1440 - disparity_loss: 2.4416 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0251 - tf_op_layer_mul_1_loss: 39.2582 - tf_op_layer_mul_loss: 30.8391 - tf_op_layer_mul_2_loss: 30.4628 - tf_op_layer_mul_3_loss: 95.3034 - tf_op_layer_mul_4_loss: 6.5555 - tf_op_layer_mul_5_loss: 37.8974 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2903 - tf_op_layer_mul_8_loss: 34.6710 - val_loss: 417.4969 - val_fx_loss: 4.0278 - val_fy_loss: 4.0212 - val_u0_loss: 0.1712 - val_v0_loss: 0.2128 - val_baseline_loss: 0.1429 - val_disparity_loss: 2.7316 - val_x_loss: 0.2005 - val_y_loss: 0.1248 - val_z_loss: 0.1249 - val_pitch_loss: 0.0239 - val_tf_op_layer_mul_1_loss: 44.1367 - val_tf_op_layer_mul_loss: 34.1299 - val_tf_op_layer_mul_2_loss: 33.8115 - val_tf_op_layer_mul_3_loss: 95.6683 - val_tf_op_layer_mul_4_loss: 6.6246 - val_tf_op_layer_mul_5_loss: 37.8892 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4676 - val_tf_op_layer_mul_8_loss: 34.9935 - 303s/epoch - 7ms/sample
# Epoch 28/100
# 44520/44520 - 304s - loss: 400.7707 - fx_loss: 2.0189 - fy_loss: 2.0505 - u0_loss: 0.2233 - v0_loss: 0.2579 - baseline_loss: 0.1441 - disparity_loss: 2.3833 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0244 - tf_op_layer_mul_1_loss: 39.2586 - tf_op_layer_mul_loss: 30.8425 - tf_op_layer_mul_2_loss: 30.4673 - tf_op_layer_mul_3_loss: 95.3084 - tf_op_layer_mul_4_loss: 6.5560 - tf_op_layer_mul_5_loss: 37.8957 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2813 - tf_op_layer_mul_8_loss: 34.6749 - val_loss: 421.2769 - val_fx_loss: 5.4994 - val_fy_loss: 5.7638 - val_u0_loss: 0.4617 - val_v0_loss: 0.4235 - val_baseline_loss: 0.1428 - val_disparity_loss: 2.8000 - val_x_loss: 0.2000 - val_y_loss: 0.1275 - val_z_loss: 0.1252 - val_pitch_loss: 0.0256 - val_tf_op_layer_mul_1_loss: 44.1304 - val_tf_op_layer_mul_loss: 34.1265 - val_tf_op_layer_mul_2_loss: 33.8091 - val_tf_op_layer_mul_3_loss: 95.6702 - val_tf_op_layer_mul_4_loss: 6.6235 - val_tf_op_layer_mul_5_loss: 37.8860 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4899 - val_tf_op_layer_mul_8_loss: 34.9924 - 304s/epoch - 7ms/sample
# Epoch 29/100
# 44520/44520 - 304s - loss: 400.6476 - fx_loss: 1.9880 - fy_loss: 2.0195 - u0_loss: 0.2227 - v0_loss: 0.2380 - baseline_loss: 0.1440 - disparity_loss: 2.3416 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0245 - tf_op_layer_mul_1_loss: 39.2558 - tf_op_layer_mul_loss: 30.8390 - tf_op_layer_mul_2_loss: 30.4636 - tf_op_layer_mul_3_loss: 95.3008 - tf_op_layer_mul_4_loss: 6.5563 - tf_op_layer_mul_5_loss: 37.8947 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2823 - tf_op_layer_mul_8_loss: 34.6731 - val_loss: 421.6414 - val_fx_loss: 5.6380 - val_fy_loss: 5.6328 - val_u0_loss: 0.6162 - val_v0_loss: 0.6180 - val_baseline_loss: 0.1433 - val_disparity_loss: 2.7981 - val_x_loss: 0.2000 - val_y_loss: 0.1285 - val_z_loss: 0.1255 - val_pitch_loss: 0.0243 - val_tf_op_layer_mul_1_loss: 44.1405 - val_tf_op_layer_mul_loss: 34.1403 - val_tf_op_layer_mul_2_loss: 33.8218 - val_tf_op_layer_mul_3_loss: 95.6485 - val_tf_op_layer_mul_4_loss: 6.6239 - val_tf_op_layer_mul_5_loss: 37.8890 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4987 - val_tf_op_layer_mul_8_loss: 34.9781 - 304s/epoch - 7ms/sample
# Epoch 30/100
# 44520/44520 - 303s - loss: 400.4942 - fx_loss: 1.9350 - fy_loss: 1.9619 - u0_loss: 0.2272 - v0_loss: 0.2447 - baseline_loss: 0.1440 - disparity_loss: 2.2898 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.
- tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2921 - tf_op_layer_mul_8_loss: 34.6699 - val_loss: 417.4343 - val_fx_loss: 4.0891 - val_fy_loss: 4.0736 - val_u0_loss: 0.1079 - val_v0_loss: 0.0818 - val_baseline_loss: 0.1432 - val_disparity_loss: 2.7522 - val_x_loss: 0.2002 - val_y_loss: 0.1248 - val_z_loss: 0.1249 - val_pitch_loss: 0.0256 - val_tf_op_layer_mul_1_loss: 44.1290 - val_tf_op_layer_mul_loss: 34.1258 - val_tf_op_layer_mul_2_loss: 33.8086 - val_tf_op_layer_mul_3_loss: 95.6673 - val_tf_op_layer_mul_4_loss: 6.6222 - val_tf_op_layer_mul_5_loss: 37.8871 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4789 - val_tf_op_layer_mul_8_loss: 34.9850 - 301s/epoch - 7ms/sample
# Epoch 33/100
# 44520/44520 - 302s - loss: 399.9774 - fx_loss: 1.7920 - fy_loss: 1.8102 - u0_loss: 0.1778 - v0_loss: 0.2530 - baseline_loss: 0.1440 - disparity_loss: 2.1134 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0239 - tf_op_layer_mul_1_loss: 39.2750 - tf_op_layer_mul_loss: 30.8552 - tf_op_layer_mul_2_loss: 30.4810 - tf_op_layer_mul_3_loss: 95.3050 - tf_op_layer_mul_4_loss: 6.5569 - tf_op_layer_mul_5_loss: 37.8949 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2825 - tf_op_layer_mul_8_loss: 34.6790 - val_loss: 417.0171 - val_fx_loss: 3.7829 - val_fy_loss: 3.7582 - val_u0_loss: 0.0990 - val_v0_loss: 0.3470 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.6982 - val_x_loss: 0.2000 - val_y_loss: 0.1250 - val_z_loss: 0.1249 - val_pitch_loss: 0.0221 - val_tf_op_layer_mul_1_loss: 44.1347 - val_tf_op_layer_mul_loss: 34.1309 - val_tf_op_layer_mul_2_loss: 33.8133 - val_tf_op_layer_mul_3_loss: 95.6555 - val_tf_op_layer_mul_4_loss: 6.6209 - val_tf_op_layer_mul_5_loss: 37.8884 - val_tf_op_layer_mul_6_loss: 37.9050 - val_tf_op_layer_mul_7_loss: 80.5000 - val_tf_op_layer_mul_8_loss: 34.9852 - 302s/epoch - 7ms/sample
# Epoch 34/100
# 44520/44520 - 301s - loss: 399.7000 - fx_loss: 1.6948 - fy_loss: 1.7046 - u0_loss: 0.1927 - v0_loss: 0.2240 - baseline_loss: 0.1441 - disparity_loss: 2.0509 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0236 - tf_op_layer_mul_1_loss: 39.2536 - tf_op_layer_mul_loss: 30.8350 - tf_op_layer_mul_2_loss: 30.4588 - tf_op_layer_mul_3_loss: 95.3060 - tf_op_layer_mul_4_loss: 6.5560 - tf_op_layer_mul_5_loss: 37.8976 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2825 - tf_op_layer_mul_8_loss: 34.6742 - val_loss: 420.1753 - val_fx_loss: 5.1629 - val_fy_loss: 5.2589 - val_u0_loss: 0.6004 - val_v0_loss: 0.1418 - val_baseline_loss: 0.1432 - val_disparity_loss: 2.6872 - val_x_loss: 0.2000 - val_y_loss: 0.1253 - val_z_loss: 0.1249 - val_pitch_loss: 0.0230 - val_tf_op_layer_mul_1_loss: 44.1529 - val_tf_op_layer_mul_loss: 34.1688 - val_tf_op_layer_mul_2_loss: 33.8557 - val_tf_op_layer_mul_3_loss: 95.6518 - val_tf_op_layer_mul_4_loss: 6.6214 - val_tf_op_layer_mul_5_loss: 37.8872 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.
- tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2750 - tf_op_layer_mul_8_loss: 34.6736 - val_loss: 421.4153 - val_fx_loss: 6.0908 - val_fy_loss: 6.0309 - val_u0_loss: 0.1676 - val_v0_loss: 0.0717 - val_baseline_loss: 0.1446 - val_disparity_loss: 2.7274 - val_x_loss: 0.2000 - val_y_loss: 0.1250 - val_z_loss: 0.1249 - val_pitch_loss: 0.0226 - val_tf_op_layer_mul_1_loss: 44.1291 - val_tf_op_layer_mul_loss: 34.1248 - val_tf_op_layer_mul_2_loss: 33.8075 - val_tf_op_layer_mul_3_loss: 95.6715 - val_tf_op_layer_mul_4_loss: 6.6209 - val_tf_op_layer_mul_5_loss: 37.8861 - val_tf_op_layer_mul_6_loss: 37.9050 - val_tf_op_layer_mul_7_loss: 80.4744 - val_tf_op_layer_mul_8_loss: 34.9864 - 299s/epoch - 7ms/sample
# Epoch 38/100
# 44520/44520 - 300s - loss: 399.2713 - fx_loss: 1.5919 - fy_loss: 1.5952 - u0_loss: 0.1851 - v0_loss: 0.2401 - baseline_loss: 0.1440 - disparity_loss: 1.8239 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0232 - tf_op_layer_mul_1_loss: 39.2613 - tf_op_layer_mul_loss: 30.8430 - tf_op_layer_mul_2_loss: 30.4666 - tf_op_layer_mul_3_loss: 95.3018 - tf_op_layer_mul_4_loss: 6.5546 - tf_op_layer_mul_5_loss: 37.8968 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2759 - tf_op_layer_mul_8_loss: 34.6721 - val_loss: 418.2783 - val_fx_loss: 4.5118 - val_fy_loss: 4.5735 - val_u0_loss: 0.0387 - val_v0_loss: 0.1383 - val_baseline_loss: 0.1433 - val_disparity_loss: 2.6927 - val_x_loss: 0.2000 - val_y_loss: 0.1248 - val_z_loss: 0.1251 - val_pitch_loss: 0.0226 - val_tf_op_layer_mul_1_loss: 44.1301 - val_tf_op_layer_mul_loss: 34.1266 - val_tf_op_layer_mul_2_loss: 33.8073 - val_tf_op_layer_mul_3_loss: 95.6609 - val_tf_op_layer_mul_4_loss: 6.6224 - val_tf_op_layer_mul_5_loss: 37.8910 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4394 - val_tf_op_layer_mul_8_loss: 35.0009 - 300s/epoch - 7ms/sample
# Epoch 39/100
# 44520/44520 - 302s - loss: 399.1711 - fx_loss: 1.5561 - fy_loss: 1.5595 - u0_loss: 0.1794 - v0_loss: 0.2327 - baseline_loss: 0.1439 - disparity_loss: 1.8084 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0232 - tf_op_layer_mul_1_loss: 39.2573 - tf_op_layer_mul_loss: 30.8389 - tf_op_layer_mul_2_loss: 30.4634 - tf_op_layer_mul_3_loss: 95.3066 - tf_op_layer_mul_4_loss: 6.5567 - tf_op_layer_mul_5_loss: 37.8954 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2866 - tf_op_layer_mul_8_loss: 34.6777 - val_loss: 414.7641 - val_fx_loss: 2.2102 - val_fy_loss: 2.2080 - val_u0_loss: 0.3762 - val_v0_loss: 0.8897 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.7511 - val_x_loss: 0.2006 - val_y_loss: 0.1254 - val_z_loss: 0.1252 - val_pitch_loss: 0.0225 - val_tf_op_layer_mul_1_loss: 44.1920 - val_tf_op_layer_mul_loss: 34.1853 - val_tf_op_layer_mul_2_loss: 33.8744 - val_tf_op_layer_mul_3_loss: 95.6532 - val_tf_op_layer_mul_4_loss: 6.6221 - val_tf_op_layer_mul_5_loss: 37.8869 - val_tf_op_layer_mul_6_loss: 37.9049 - val_tf_op_layer_mul_7_loss: 80.4857 - val_tf_op_layer_mul_8_loss: 34.9870 - 302s/epoch - 7ms/sample
# Epoch 40/100
# 44520/44520 - 301s - loss: 399.0587 - fx_loss: 1.5434 - fy_loss: 1.5429 - u0_loss: 0.1890 - v0_loss: 0.2297 - baseline_loss: 0.1440 - disparity_loss: 1.7182 - x_loss: 0.2004 - y_loss: 0.1253 - z_loss: 0.1251 - pitch_loss: 0.0236 - tf_op_layer_mul_1_loss: 39.2778 - tf_op_layer_mul_loss: 30.8535 - tf_op_layer_mul_2_loss: 30.4752 - tf_op_layer_mul_3_loss: 95.3007 - tf_op_layer_mul_4_loss: 6.5572 - tf_op_layer_mul_5_loss: 37.8968 - tf_op_layer_mul_6_loss: 37.9064 - tf_op_layer_mul_7_loss: 80.2912 - tf_op_layer_mul_8_loss: 34.6713 - val_loss: 421.4927 - val_fx_loss: 5.7752 - val_fy_loss: 5.7837 - val_u0_loss: 0.3631 - val_v0_loss: 0.3528 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.8840 - val_x_loss: 0.2000 - val_y_loss: 0.1249 - val_z_loss: 0.1249 - val_pitch_loss: 0.0266 - val_tf_op_layer_mul_1_loss: 44.1784 - val_tf_op_layer_mul_loss: 34.1744 - val_tf_op_layer_mul_2_loss: 33.8547 - val_tf_op_layer_mul_3_loss: 95.6439 - val_tf_op_layer_mul_4_loss: 6.6222 - val_tf_op_layer_mul_5_loss: 37.8851 - val_tf_op_layer_mul_6_loss: 37.9050 - val_tf_op_layer_mul_7_loss: 80.4650 - val_tf_op_layer_mul_8_loss: 34.9761 - 301s/epoch - 7ms/sample
# Epoch 41/100
# ...
# Epoch 88/100
# 44520/44520 - 302s - loss: 210.6514 - fx_loss: 0.9358 - fy_loss: 0.9298 - u0_loss: 0.1392 - v0_loss: 0.1730 - baseline_loss: 0.1438 - disparity_loss: 0.8250 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1252 - pitch_loss: 0.0109 - tf_op_layer_mul_1_loss: 39.2623 - tf_op_layer_mul_loss: 30.8430 - tf_op_layer_mul_2_loss: 30.4673 - tf_op_layer_mul_3_loss: 0.9969 - tf_op_layer_mul_4_loss: 6.5552 - tf_op_layer_mul_5_loss: 0.5082 - tf_op_layer_mul_6_loss: 0.0890 - tf_op_layer_mul_7_loss: 80.2837 - tf_op_layer_mul_8_loss: 18.0163 - val_loss: 232.8550 - val_fx_loss: 3.4189 - val_fy_loss: 3.3221 - val_u0_loss: 0.4322 - val_v0_loss: 0.3486 - val_baseline_loss: 0.1429 - val_disparity_loss: 2.7076 - val_x_loss: 0.2001 - val_y_loss: 0.1264 - val_z_loss: 0.1251 - val_pitch_loss: 0.0135 - val_tf_op_layer_mul_1_loss: 44.1324 - val_tf_op_layer_mul_loss: 34.1259 - val_tf_op_layer_mul_2_loss: 33.8076 - val_tf_op_layer_mul_3_loss: 3.4276 - val_tf_op_layer_mul_4_loss: 6.6204 - val_tf_op_layer_mul_5_loss: 0.6896 - val_tf_op_layer_mul_6_loss: 0.1712 - val_tf_op_layer_mul_7_loss: 80.4760 - val_tf_op_layer_mul_8_loss: 18.4714 - 302s/epoch - 7ms/sample
# Epoch 89/100
# 44520/44520 - 302s - loss: 210.7497 - fx_loss: 0.9523 - fy_loss: 0.9510 - u0_loss: 0.1580 - v0_loss: 0.1686 - baseline_loss: 0.1439 - disparity_loss: 0.8351 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1252 - pitch_loss: 0.0112 - tf_op_layer_mul_1_loss: 39.2581 - tf_op_layer_mul_loss: 30.8398 - tf_op_layer_mul_2_loss: 30.4636 - tf_op_layer_mul_3_loss: 1.0179 - tf_op_layer_mul_4_loss: 6.5572 - tf_op_layer_mul_5_loss: 0.5239 - tf_op_layer_mul_6_loss: 0.0872 - tf_op_layer_mul_7_loss: 80.2896 - tf_op_layer_mul_8_loss: 18.0177 - val_loss: 233.1624 - val_fx_loss: 3.5114 - val_fy_loss: 3.5528 - val_u0_loss: 0.5579 - val_v0_loss: 0.2864 - val_baseline_loss: 0.1429 - val_disparity_loss: 2.6655 - val_x_loss: 0.2000 - val_y_loss: 0.1267 - val_z_loss: 0.1254 - val_pitch_loss: 0.0138 - val_tf_op_layer_mul_1_loss: 44.1328 - val_tf_op_layer_mul_loss: 34.1276 - val_tf_op_layer_mul_2_loss: 33.8095 - val_tf_op_layer_mul_3_loss: 3.5129 - val_tf_op_layer_mul_4_loss: 6.6207 - val_tf_op_layer_mul_5_loss: 0.6115 - val_tf_op_layer_mul_6_loss: 0.1473 - val_tf_op_layer_mul_7_loss: 80.5297 - val_tf_op_layer_mul_8_loss: 18.4335 - 302s/epoch - 7ms/sample
# Epoch 90/100
# 44520/44520 - 302s - loss: 210.6690 - fx_loss: 0.9342 - fy_loss: 0.9247 - u0_loss: 0.1497 - v0_loss: 0.1571 - baseline_loss: 0.1439 - disparity_loss: 0.8363 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1254 - pitch_loss: 0.0118 - tf_op_layer_mul_1_loss: 39.2519 - tf_op_layer_mul_loss: 30.8353 - tf_op_layer_mul_2_loss: 30.4595 - tf_op_layer_mul_3_loss: 1.0010 - tf_op_layer_mul_4_loss: 6.5563 - tf_op_layer_mul_5_loss: 0.5471 - tf_op_layer_mul_6_loss: 0.0819 - tf_op_layer_mul_7_loss: 80.2777 - tf_op_layer_mul_8_loss: 18.0004 - val_loss: 229.2260 - val_fx_loss: 2.0719 - val_fy_loss: 1.8973 - val_u0_loss: 0.9654 - val_v0_loss: 0.1818 - val_baseline_loss: 0.1429 - val_disparity_loss: 2.6977 - val_x_loss: 0.2000 - val_y_loss: 0.1258 - val_z_loss: 0.1251 - val_pitch_loss: 0.0147 - val_tf_op_layer_mul_1_loss: 44.1336 - val_tf_op_layer_mul_loss: 34.1268 - val_tf_op_layer_mul_2_loss: 33.8087 - val_tf_op_layer_mul_3_loss: 2.1272 - val_tf_op_layer_mul_4_loss: 6.6214 - val_tf_op_layer_mul_5_loss: 0.9338 - val_tf_op_layer_mul_6_loss: 0.1005 - val_tf_op_layer_mul_7_loss: 80.4674 - val_tf_op_layer_mul_8_loss: 18.3690 - 302s/epoch - 7ms/sample
# Epoch 91/100
# 44520/44520 - 304s - loss: 210.6836 - fx_loss: 0.9562 - fy_loss: 0.9496 - u0_loss: 0.1506 - v0_loss: 0.1743 - baseline_loss: 0.1439 - disparity_loss: 0.8150 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1254 - pitch_loss: 0.0105 - tf_op_layer_mul_1_loss: 39.2555 - tf_op_layer_mul_loss: 30.8359 - tf_op_layer_mul_2_loss: 30.4602 - tf_op_layer_mul_3_loss: 1.0129 - tf_op_layer_mul_4_loss: 6.5572 - tf_op_layer_mul_5_loss: 0.4893 - tf_op_layer_mul_6_loss: 0.0895 - tf_op_layer_mul_7_loss: 80.3063 - tf_op_layer_mul_8_loss: 18.0101 - val_loss: 227.5356 - val_fx_loss: 1.8746 - val_fy_loss: 1.9000 - val_u0_loss: 0.2530 - val_v0_loss: 0.1287 - val_baseline_loss: 0.1428 - val_disparity_loss: 2.6401 - val_x_loss: 0.2000 - val_y_loss: 0.1250 - val_z_loss: 0.1249 - val_pitch_loss: 0.0131 - val_tf_op_layer_mul_1_loss: 44.3133 - val_tf_op_layer_mul_loss: 34.2840 - val_tf_op_layer_mul_2_loss: 33.9472 - val_tf_op_layer_mul_3_loss: 1.9480 - val_tf_op_layer_mul_4_loss: 6.6242 - val_tf_op_layer_mul_5_loss: 0.6023 - val_tf_op_layer_mul_6_loss: 0.0631 - val_tf_op_layer_mul_7_loss: 80.5222 - val_tf_op_layer_mul_8_loss: 18.2436 - 304s/epoch - 7ms/sample
# Epoch 92/100
# 44520/44520 - 303s - loss: 210.4811 - fx_loss: 0.9104 - fy_loss: 0.9079 - u0_loss: 0.1542 - v0_loss: 0.1664 - baseline_loss: 0.1439 - disparity_loss: 0.7847 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1252 - pitch_loss: 0.0100 - tf_op_layer_mul_1_loss: 39.2755 - tf_op_layer_mul_loss: 30.8531 - tf_op_layer_mul_2_loss: 30.4768 - tf_op_layer_mul_3_loss: 0.9679 - tf_op_layer_mul_4_loss: 6.5546 - tf_op_layer_mul_5_loss: 0.4643 - tf_op_layer_mul_6_loss: 0.0857 - tf_op_layer_mul_7_loss: 80.3026 - tf_op_layer_mul_8_loss: 17.9978 - val_loss: 228.3428 - val_fx_loss: 2.1507 - val_fy_loss: 1.9110 - val_u0_loss: 0.1486 - val_v0_loss: 0.1479 - val_baseline_loss: 0.1429 - val_disparity_loss: 2.6625 - val_x_loss: 0.2000 - val_y_loss: 0.1249 - val_z_loss: 0.1262 - val_pitch_loss: 0.0163 - val_tf_op_layer_mul_1_loss: 44.1627 - val_tf_op_layer_mul_loss: 34.1465 - val_tf_op_layer_mul_2_loss: 33.8270 - val_tf_op_layer_mul_3_loss: 2.3909 - val_tf_op_layer_mul_4_loss: 6.6203 - val_tf_op_layer_mul_5_loss: 0.7493 - val_tf_op_layer_mul_6_loss: 0.0774 - val_tf_op_layer_mul_7_loss: 80.4640 - val_tf_op_layer_mul_8_loss: 18.2222 - 303s/epoch - 7ms/sample
# Epoch 93/100
# 44520/44520 - 302s - loss: 210.4756 - fx_loss: 0.9228 - fy_loss: 0.9179 - u0_loss: 0.1636 - v0_loss: 0.1530 - baseline_loss: 0.1439 - disparity_loss: 0.7781 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1252 - pitch_loss: 0.0095 - tf_op_layer_mul_1_loss: 39.2577 - tf_op_layer_mul_loss: 30.8396 - tf_op_layer_mul_2_loss: 30.4633 - tf_op_layer_mul_3_loss: 0.9694 - tf_op_layer_mul_4_loss: 6.5570 - tf_op_layer_mul_5_loss: 0.4460 - tf_op_layer_mul_6_loss: 0.0788 - tf_op_layer_mul_7_loss: 80.2974 - tf_op_layer_mul_8_loss: 18.0113 - val_loss: 229.7551 - val_fx_loss: 2.6803 - val_fy_loss: 2.4199 - val_u0_loss: 0.0435 - val_v0_loss: 0.2679 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.7160 - val_x_loss: 0.2000 - val_y_loss: 0.1248 - val_z_loss: 0.1255 - val_pitch_loss: 0.0153 - val_tf_op_layer_mul_1_loss: 44.1678 - val_tf_op_layer_mul_loss: 34.1657 - val_tf_op_layer_mul_2_loss: 33.8480 - val_tf_op_layer_mul_3_loss: 2.6704 - val_tf_op_layer_mul_4_loss: 6.6239 - val_tf_op_layer_mul_5_loss: 0.7369 - val_tf_op_layer_mul_6_loss: 0.1155 - val_tf_op_layer_mul_7_loss: 80.4903 - val_tf_op_layer_mul_8_loss: 18.2156 - 302s/epoch - 7ms/sample
# Epoch 94/100
# 44520/44520 - 302s - loss: 210.4205 - fx_loss: 0.9018 - fy_loss: 0.8952 - u0_loss: 0.1506 - v0_loss: 0.1800 - baseline_loss: 0.1439 - disparity_loss: 0.7769 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1254 - pitch_loss: 0.0094 - tf_op_layer_mul_1_loss: 39.2693 - tf_op_layer_mul_loss: 30.8502 - tf_op_layer_mul_2_loss: 30.4732 - tf_op_layer_mul_3_loss: 0.9512 - tf_op_layer_mul_4_loss: 6.5567 - tf_op_layer_mul_5_loss: 0.4381 - tf_op_layer_mul_6_loss: 0.0920 - tf_op_layer_mul_7_loss: 80.2826 - tf_op_layer_mul_8_loss: 17.9955 - val_loss: 227.9100 - val_fx_loss: 2.0948 - val_fy_loss: 2.1423 - val_u0_loss: 0.0955 - val_v0_loss: 0.0382 - val_baseline_loss: 0.1428 - val_disparity_loss: 2.6431 - val_x_loss: 0.2000 - val_y_loss: 0.1249 - val_z_loss: 0.1249 - val_pitch_loss: 0.0136 - val_tf_op_layer_mul_1_loss: 44.1502 - val_tf_op_layer_mul_loss: 34.1439 - val_tf_op_layer_mul_2_loss: 33.8285 - val_tf_op_layer_mul_3_loss: 2.1450 - val_tf_op_layer_mul_4_loss: 6.6238 - val_tf_op_layer_mul_5_loss: 0.6413 - val_tf_op_layer_mul_6_loss: 0.0315 - val_tf_op_layer_mul_7_loss: 80.5139 - val_tf_op_layer_mul_8_loss: 18.1971 - 302s/epoch - 7ms/sample
# Epoch 95/100
# 44520/44520 - 302s - loss: 210.4733 - fx_loss: 0.9182 - fy_loss: 0.9137 - u0_loss: 0.1417 - v0_loss: 0.1604 - baseline_loss: 0.1439 - disparity_loss: 0.7846 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1252 - pitch_loss: 0.0099 - tf_op_layer_mul_1_loss: 39.2736 - tf_op_layer_mul_loss: 30.8479 - tf_op_layer_mul_2_loss: 30.4708 - tf_op_layer_mul_3_loss: 0.9718 - tf_op_layer_mul_4_loss: 6.5559 - tf_op_layer_mul_5_loss: 0.4579 - tf_op_layer_mul_6_loss: 0.0823 - tf_op_layer_mul_7_loss: 80.2808 - tf_op_layer_mul_8_loss: 18.0067 - val_loss: 235.7193 - val_fx_loss: 4.5996 - val_fy_loss: 4.7027 - val_u0_loss: 0.1998 - val_v0_loss: 0.0738 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.6263 - val_x_loss: 0.2001 - val_y_loss: 0.1248 - val_z_loss: 0.1253 - val_pitch_loss: 0.0122 - val_tf_op_layer_mul_1_loss: 44.1244 - val_tf_op_layer_mul_loss: 34.1239 - val_tf_op_layer_mul_2_loss: 33.8056 - val_tf_op_layer_mul_3_loss: 4.6360 - val_tf_op_layer_mul_4_loss: 6.6224 - val_tf_op_layer_mul_5_loss: 0.6007 - val_tf_op_layer_mul_6_loss: 0.0397 - val_tf_op_layer_mul_7_loss: 80.4741 - val_tf_op_layer_mul_8_loss: 18.3486 - 302s/epoch - 7ms/sample
# Epoch 96/100
# 44520/44520 - 303s - loss: 210.4409 - fx_loss: 0.9365 - fy_loss: 0.9329 - u0_loss: 0.1518 - v0_loss: 0.1454 - baseline_loss: 0.1439 - disparity_loss: 0.7592 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1252 - pitch_loss: 0.0090 - tf_op_layer_mul_1_loss: 39.2542 - tf_op_layer_mul_loss: 30.8369 - tf_op_layer_mul_2_loss: 30.4610 - tf_op_layer_mul_3_loss: 0.9855 - tf_op_layer_mul_4_loss: 6.5573 - tf_op_layer_mul_5_loss: 0.4180 - tf_op_layer_mul_6_loss: 0.0748 - tf_op_layer_mul_7_loss: 80.2862 - tf_op_layer_mul_8_loss: 17.9977 - val_loss: 231.2771 - val_fx_loss: 3.1791 - val_fy_loss: 2.2780 - val_u0_loss: 0.5980 - val_v0_loss: 0.1911 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.6728 - val_x_loss: 0.2001 - val_y_loss: 0.1258 - val_z_loss: 0.1256 - val_pitch_loss: 0.0141 - val_tf_op_layer_mul_1_loss: 44.1404 - val_tf_op_layer_mul_loss: 34.1349 - val_tf_op_layer_mul_2_loss: 33.8160 - val_tf_op_layer_mul_3_loss: 3.3860 - val_tf_op_layer_mul_4_loss: 6.6225 - val_tf_op_layer_mul_5_loss: 0.6811 - val_tf_op_layer_mul_6_loss: 0.1048 - val_tf_op_layer_mul_7_loss: 80.5214 - val_tf_op_layer_mul_8_loss: 18.3154 - 303s/epoch - 7ms/sample
# Epoch 97/100
# 44520/44520 - 303s - loss: 210.4721 - fx_loss: 0.9232 - fy_loss: 0.9109 - u0_loss: 0.1624 - v0_loss: 0.1816 - baseline_loss: 0.1438 - disparity_loss: 0.7599 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1254 - pitch_loss: 0.0091 - tf_op_layer_mul_1_loss: 39.3124 - tf_op_layer_mul_loss: 30.8757 - tf_op_layer_mul_2_loss: 30.5006 - tf_op_layer_mul_3_loss: 0.9750 - tf_op_layer_mul_4_loss: 6.5564 - tf_op_layer_mul_5_loss: 0.4270 - tf_op_layer_mul_6_loss: 0.0923 - tf_op_layer_mul_7_loss: 80.2915 - tf_op_layer_mul_8_loss: 18.0036 - val_loss: 236.9741 - val_fx_loss: 4.8313 - val_fy_loss: 4.5554 - val_u0_loss: 0.2823 - val_v0_loss: 0.4830 - val_baseline_loss: 0.1428 - val_disparity_loss: 2.6471 - val_x_loss: 0.2000 - val_y_loss: 0.1253 - val_z_loss: 0.1257 - val_pitch_loss: 0.0140 - val_tf_op_layer_mul_1_loss: 44.1275 - val_tf_op_layer_mul_loss: 34.1244 - val_tf_op_layer_mul_2_loss: 33.8070 - val_tf_op_layer_mul_3_loss: 4.9683 - val_tf_op_layer_mul_4_loss: 6.6222 - val_tf_op_layer_mul_5_loss: 0.7631 - val_tf_op_layer_mul_6_loss: 0.2316 - val_tf_op_layer_mul_7_loss: 80.5092 - val_tf_op_layer_mul_8_loss: 18.3361 - 303s/epoch - 7ms/sample
# Epoch 98/100
# 44520/44520 - 303s - loss: 210.3609 - fx_loss: 0.8983 - fy_loss: 0.8937 - u0_loss: 0.1529 - v0_loss: 0.1732 - baseline_loss: 0.1439 - disparity_loss: 0.7502 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1254 - pitch_loss: 0.0090 - tf_op_layer_mul_1_loss: 39.2547 - tf_op_layer_mul_loss: 30.8373 - tf_op_layer_mul_2_loss: 30.4611 - tf_op_layer_mul_3_loss: 0.9492 - tf_op_layer_mul_4_loss: 6.5564 - tf_op_layer_mul_5_loss: 0.4170 - tf_op_layer_mul_6_loss: 0.0882 - tf_op_layer_mul_7_loss: 80.2968 - tf_op_layer_mul_8_loss: 18.0010 - val_loss: 229.8481 - val_fx_loss: 2.5775 - val_fy_loss: 2.4685 - val_u0_loss: 0.3194 - val_v0_loss: 0.2631 - val_baseline_loss: 0.1431 - val_disparity_loss: 2.6749 - val_x_loss: 0.2001 - val_y_loss: 0.1248 - val_z_loss: 0.1251 - val_pitch_loss: 0.0132 - val_tf_op_layer_mul_1_loss: 44.1326 - val_tf_op_layer_mul_loss: 34.1310 - val_tf_op_layer_mul_2_loss: 33.8141 - val_tf_op_layer_mul_3_loss: 2.6587 - val_tf_op_layer_mul_4_loss: 6.6233 - val_tf_op_layer_mul_5_loss: 0.6785 - val_tf_op_layer_mul_6_loss: 0.1195 - val_tf_op_layer_mul_7_loss: 80.4347 - val_tf_op_layer_mul_8_loss: 18.2013 - 303s/epoch - 7ms/sample
# Epoch 99/100
# 44520/44520 - 302s - loss: 210.2860 - fx_loss: 0.9079 - fy_loss: 0.9020 - u0_loss: 0.1365 - v0_loss: 0.1426 - baseline_loss: 0.1439 - disparity_loss: 0.7376 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1253 - pitch_loss: 0.0085 - tf_op_layer_mul_1_loss: 39.2528 - tf_op_layer_mul_loss: 30.8351 - tf_op_layer_mul_2_loss: 30.4592 - tf_op_layer_mul_3_loss: 0.9510 - tf_op_layer_mul_4_loss: 6.5567 - tf_op_layer_mul_5_loss: 0.3986 - tf_op_layer_mul_6_loss: 0.0729 - tf_op_layer_mul_7_loss: 80.2922 - tf_op_layer_mul_8_loss: 18.0030 - val_loss: 233.6430 - val_fx_loss: 3.7925 - val_fy_loss: 4.1137 - val_u0_loss: 0.1024 - val_v0_loss: 0.2000 - val_baseline_loss: 0.1427 - val_disparity_loss: 2.6494 - val_x_loss: 0.1999 - val_y_loss: 0.1252 - val_z_loss: 0.1251 - val_pitch_loss: 0.0149 - val_tf_op_layer_mul_1_loss: 44.1721 - val_tf_op_layer_mul_loss: 34.1688 - val_tf_op_layer_mul_2_loss: 33.8472 - val_tf_op_layer_mul_3_loss: 3.8353 - val_tf_op_layer_mul_4_loss: 6.6225 - val_tf_op_layer_mul_5_loss: 0.7322 - val_tf_op_layer_mul_6_loss: 0.0863 - val_tf_op_layer_mul_7_loss: 80.4901 - val_tf_op_layer_mul_8_loss: 18.2553 - 302s/epoch - 7ms/sample
# Epoch 100/100
# 44520/44520 - 302s - loss: 210.1802 - fx_loss: 0.8566 - fy_loss: 0.8564 - u0_loss: 0.1402 - v0_loss: 0.1864 - baseline_loss: 0.1439 - disparity_loss: 0.7356 - x_loss: 0.2003 - y_loss: 0.1253 - z_loss: 0.1253 - pitch_loss: 0.0082 - tf_op_layer_mul_1_loss: 39.2588 - tf_op_layer_mul_loss: 30.8381 - tf_op_layer_mul_2_loss: 30.4622 - tf_op_layer_mul_3_loss: 0.8964 - tf_op_layer_mul_4_loss: 6.5577 - tf_op_layer_mul_5_loss: 0.3829 - tf_op_layer_mul_6_loss: 0.0947 - tf_op_layer_mul_7_loss: 80.2791 - tf_op_layer_mul_8_loss: 17.9953 - val_loss: 228.8345 - val_fx_loss: 2.1092 - val_fy_loss: 2.0445 - val_u0_loss: 0.2126 - val_v0_loss: 0.2892 - val_baseline_loss: 0.1433 - val_disparity_loss: 2.6637 - val_x_loss: 0.2000 - val_y_loss: 0.1248 - val_z_loss: 0.1250 - val_pitch_loss: 0.0213 - val_tf_op_layer_mul_1_loss: 44.1269 - val_tf_op_layer_mul_loss: 34.1244 - val_tf_op_layer_mul_2_loss: 33.8069 - val_tf_op_layer_mul_3_loss: 2.3951 - val_tf_op_layer_mul_4_loss: 6.6216 - val_tf_op_layer_mul_5_loss: 0.9238 - val_tf_op_layer_mul_6_loss: 0.1257 - val_tf_op_layer_mul_7_loss: 80.5009 - val_tf_op_layer_mul_8_loss: 18.1810 - 302s/epoch - 7ms/sample
